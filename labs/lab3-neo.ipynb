# %% [markdown]
# COMP 215 - LAB 3 (NEO)
# ----------------
# #### Name: Ben Blair
# #### Date: 23/01/2023
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from dataclasses import dataclass
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# ## Fetch Complete Data for One Asteroid (from Lab 2)
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the asteroid with the given id...

# %%
API_KEY = 'GT5a6VBQVVTnT8H1jSPfja2DfDMaC1d0UsYeWsYW'

id = '2226554' # Asteroid ID taken from Lab 2
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

pprint(data)
# Out:
# {'absolute_magnitude_h': 19.64,
#  'close_approach_data': [{'close_approach_date': '1900-10-30',
#                           'close_approach_date_full': '1900-Oct-30 21:14',
#                           'epoch_date_close_approach': -2182819560000,
#                           'miss_distance': {'astronomical': '0.4183489529',
#                                             'kilometers': '62584112.270570323',
#                                             'lunar': '162.7377426781',
#                                             'miles': '38887964.1060755374'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30027.9637577316',
#                                                 'kilometers_per_second': '8.3411010438',
#                                                 'miles_per_hour': '18658.2089249083'}},
#                          {'close_approach_date': '1901-06-26',
#                           'close_approach_date_full': '1901-Jun-26 20:27',
#                           'epoch_date_close_approach': -2162172780000,
#                           'miss_distance': {'astronomical': '0.0308797847',
#                                             'kilometers': '4619550.017178589',
#                                             'lunar': '12.0122362483',
#                                             'miles': '2870455.2758949682'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33429.0363049198',
#                                                 'kilometers_per_second': '9.285843418',
#                                                 'miles_per_hour': '20771.5031417987'}},
#                          {'close_approach_date': '1907-01-08',
#                           'close_approach_date_full': '1907-Jan-08 04:37',
#                           'epoch_date_close_approach': -1987528980000,
#                           'miss_distance': {'astronomical': '0.1240282082',
#                                             'kilometers': '18554355.766636534',
#                                             'lunar': '48.2469729898',
#                                             'miles': '11529142.0599668092'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24041.8524771157',
#                                                 'kilometers_per_second': '6.6782923548',
#                                                 'miles_per_hour': '14938.67216835'}},
#                          {'close_approach_date': '1907-09-06',
#                           'close_approach_date_full': '1907-Sep-06 10:51',
#                           'epoch_date_close_approach': -1966684140000,
#                           'miss_distance': {'astronomical': '0.4147266023',
#                                             'kilometers': '62042216.336417101',
#                                             'lunar': '161.3286482947',
#                                             'miles': '38551245.5864379538'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26520.1966604789',
#                                                 'kilometers_per_second': '7.3667212946',
#                                                 'miles_per_hour': '16478.6188638403'}},
#                          {'close_approach_date': '1909-08-06',
#                           'close_approach_date_full': '1909-Aug-06 06:41',
#                           'epoch_date_close_approach': -1906219140000,
#                           'miss_distance': {'astronomical': '0.1317214542',
#                                             'kilometers': '19705248.981622554',
#                                             'lunar': '51.2396456838',
#                                             'miles': '12244273.9426530852'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7812.3404746925',
#                                                 'kilometers_per_second': '2.1700945763',
#                                                 'miles_per_hour': '4854.2845577332'}},
#                          {'close_approach_date': '1912-12-22',
#                           'close_approach_date_full': '1912-Dec-22 20:01',
#                           'epoch_date_close_approach': -1799553540000,
#                           'miss_distance': {'astronomical': '0.4621503671',
#                                             'kilometers': '69136710.537878077',
#                                             'lunar': '179.7764928019',
#                                             'miles': '42959559.8669763826'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78889.9632007097',
#                                                 'kilometers_per_second': '21.9138786669',
#                                                 'miles_per_hour': '49019.1551899076'}},
#                          {'close_approach_date': '1913-10-29',
#                           'close_approach_date_full': '1913-Oct-29 19:08',
#                           'epoch_date_close_approach': -1772686320000,
#                           'miss_distance': {'astronomical': '0.423047551',
#                                             'kilometers': '63287012.53831637',
#                                             'lunar': '164.565497339',
#                                             'miles': '39324726.079531106'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30216.1966422462',
#                                                 'kilometers_per_second': '8.3933879562',
#                                                 'miles_per_hour': '18775.1695191779'}},
#                          {'close_approach_date': '1914-06-28',
#                           'close_approach_date_full': '1914-Jun-28 14:48',
#                           'epoch_date_close_approach': -1751793120000,
#                           'miss_distance': {'astronomical': '0.0438429557',
#                                             'kilometers': '6558812.787224359',
#                                             'lunar': '17.0549097673',
#                                             'miles': '4075457.2845157942'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '35203.0524829447',
#                                                 'kilometers_per_second': '9.7786256897',
#                                                 'miles_per_hour': '21873.8078053053'}},
#                          {'close_approach_date': '1919-12-30',
#                           'close_approach_date_full': '1919-Dec-30 11:27',
#                           'epoch_date_close_approach': -1578054780000,
#                           'miss_distance': {'astronomical': '0.1880337256',
#                                             'kilometers': '28129444.837924472',
#                                             'lunar': '73.1451192584',
#                                             'miles': '17478826.5183308336'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22319.4650472732',
#                                                 'kilometers_per_second': '6.199851402',
#                                                 'miles_per_hour': '13868.4476011793'}},
#                          {'close_approach_date': '1920-02-20',
#                           'close_approach_date_full': '1920-Feb-20 02:14',
#                           'epoch_date_close_approach': -1573595160000,
#                           'miss_distance': {'astronomical': '0.20169955',
#                                             'kilometers': '30173823.0599585',
#                                             'lunar': '78.46112495',
#                                             'miles': '18749144.2400873'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18956.388545382',
#                                                 'kilometers_per_second': '5.2656634848',
#                                                 'miles_per_hour': '11778.7626492125'}},
#                          {'close_approach_date': '1920-08-27',
#                           'close_approach_date_full': '1920-Aug-27 00:15',
#                           'epoch_date_close_approach': -1557272700000,
#                           'miss_distance': {'astronomical': '0.392238122',
#                                             'kilometers': '58677987.58400014',
#                                             'lunar': '152.580629458',
#                                             'miles': '36460810.774436332'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24779.592022273',
#                                                 'kilometers_per_second': '6.8832200062',
#                                                 'miles_per_hour': '15397.0748318396'}},
#                          {'close_approach_date': '1924-12-19',
#                           'close_approach_date_full': '1924-Dec-19 14:32',
#                           'epoch_date_close_approach': -1421141280000,
#                           'miss_distance': {'astronomical': '0.1361644513',
#                                             'kilometers': '20369911.884198731',
#                                             'lunar': '52.9679715557',
#                                             'miles': '12657276.3191392478'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7522.0862587508',
#                                                 'kilometers_per_second': '2.0894684052',
#                                                 'miles_per_hour': '4673.931875611'}},
#                          {'close_approach_date': '1925-12-28',
#                           'close_approach_date_full': '1925-Dec-28 17:32',
#                           'epoch_date_close_approach': -1388816880000,
#                           'miss_distance': {'astronomical': '0.3364559011',
#                                             'kilometers': '50333086.153490657',
#                                             'lunar': '130.8813455279',
#                                             'miles': '31275529.4702067866'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65215.3650106068',
#                                                 'kilometers_per_second': '18.1153791696',
#                                                 'miles_per_hour': '40522.2916645073'}},
#                          {'close_approach_date': '1926-10-17',
#                           'close_approach_date_full': '1926-Oct-17 17:33',
#                           'epoch_date_close_approach': -1363501620000,
#                           'miss_distance': {'astronomical': '0.4449026367',
#                                             'kilometers': '66556486.807703829',
#                                             'lunar': '173.0671256763',
#                                             'miles': '41356283.1859736802'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30428.213228163',
#                                                 'kilometers_per_second': '8.4522814523',
#                                                 'miles_per_hour': '18906.9083805772'}},
#                          {'close_approach_date': '1927-07-07',
#                           'close_approach_date_full': '1927-Jul-07 13:10',
#                           'epoch_date_close_approach': -1340794200000,
#                           'miss_distance': {'astronomical': '0.174697644',
#                                             'kilometers': '26134395.43641828',
#                                             'lunar': '67.957383516',
#                                             'miles': '16239160.304321064'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '48367.5389747381',
#                                                 'kilometers_per_second': '13.435427493',
#                                                 'miles_per_hour': '30053.7077590532'}},
#                          {'close_approach_date': '1932-12-06',
#                           'close_approach_date_full': '1932-Dec-06 07:38',
#                           'epoch_date_close_approach': -1169828520000,
#                           'miss_distance': {'astronomical': '0.2949624343',
#                                             'kilometers': '44125751.901294941',
#                                             'lunar': '114.7403869427',
#                                             'miles': '27418470.8200785458'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25801.9540329191',
#                                                 'kilometers_per_second': '7.1672094536',
#                                                 'miles_per_hour': '16032.3308267324'}},
#                          {'close_approach_date': '1933-04-15',
#                           'close_approach_date_full': '1933-Apr-15 01:32',
#                           'epoch_date_close_approach': -1158618480000,
#                           'miss_distance': {'astronomical': '0.2180161528',
#                                             'kilometers': '32614752.084474536',
#                                             'lunar': '84.8082834392',
#                                             'miles': '20265867.2045431568'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26552.3338547447',
#                                                 'kilometers_per_second': '7.375648293',
#                                                 'miles_per_hour': '16498.5876665773'}},
#                          {'close_approach_date': '1933-07-30',
#                           'close_approach_date_full': '1933-Jul-30 19:06',
#                           'epoch_date_close_approach': -1149396840000,
#                           'miss_distance': {'astronomical': '0.3178391439',
#                                             'kilometers': '47548058.930063493',
#                                             'lunar': '123.6394269771',
#                                             'miles': '29544993.7995744834'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19585.8848031947',
#                                                 'kilometers_per_second': '5.4405235564',
#                                                 'miles_per_hour': '12169.9071434073'}},
#                          {'close_approach_date': '1939-01-04',
#                           'close_approach_date_full': '1939-Jan-04 13:15',
#                           'epoch_date_close_approach': -978000300000,
#                           'miss_distance': {'astronomical': '0.1772544826',
#                                             'kilometers': '26516893.044912062',
#                                             'lunar': '68.9519937314',
#                                             'miles': '16476833.2971959756'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '47802.6926864899',
#                                                 'kilometers_per_second': '13.2785257462',
#                                                 'miles_per_hour': '29702.7342417804'}},
#                          {'close_approach_date': '1939-10-02',
#                           'close_approach_date_full': '1939-Oct-02 23:40',
#                           'epoch_date_close_approach': -954548400000,
#                           'miss_distance': {'astronomical': '0.4508022306',
#                                             'kilometers': '67439053.489008822',
#                                             'lunar': '175.3620677034',
#                                             'miles': '41904684.6920208636'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29767.9781480216',
#                                                 'kilometers_per_second': '8.2688828189',
#                                                 'miles_per_hour': '18496.663977586'}},
#                          {'close_approach_date': '1940-07-15',
#                           'close_approach_date_full': '1940-Jul-15 08:32',
#                           'epoch_date_close_approach': -929806080000,
#                           'miss_distance': {'astronomical': '0.334533061',
#                                             'kilometers': '50045433.37018007',
#                                             'lunar': '130.133360729',
#                                             'miles': '31096790.318902166'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64571.4313637087',
#                                                 'kilometers_per_second': '17.9365087121',
#                                                 'miles_per_hour': '40122.1763381889'}},
#                          {'close_approach_date': '1945-11-18',
#                           'close_approach_date_full': '1945-Nov-18 06:11',
#                           'epoch_date_close_approach': -761161740000,
#                           'miss_distance': {'astronomical': '0.3687527637',
#                                             'kilometers': '55164628.006133319',
#                                             'lunar': '143.4448250793',
#                                             'miles': '34277710.3644610422'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28578.7009045491',
#                                                 'kilometers_per_second': '7.938528029',
#                                                 'miles_per_hour': '17757.6933481628'}},
#                          {'close_approach_date': '1946-05-31',
#                           'close_approach_date_full': '1946-May-31 01:45',
#                           'epoch_date_close_approach': -744416100000,
#                           'miss_distance': {'astronomical': '0.1446815929',
#                                             'kilometers': '21644058.126047123',
#                                             'lunar': '56.2811396381',
#                                             'miles': '13448994.0813833774'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24131.1433453815',
#                                                 'kilometers_per_second': '6.7030953737',
#                                                 'miles_per_hour': '14994.1540414678'}},
#                          {'close_approach_date': '1952-01-09',
#                           'close_approach_date_full': '1952-Jan-09 10:55',
#                           'epoch_date_close_approach': -567349500000,
#                           'miss_distance': {'astronomical': '0.0732960842',
#                                             'kilometers': '10964938.075660654',
#                                             'lunar': '28.5121767538',
#                                             'miles': '6813296.5834548652'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33228.6655783573',
#                                                 'kilometers_per_second': '9.2301848829',
#                                                 'miles_per_hour': '20647.0005645076'}},
#                          {'close_approach_date': '1952-09-18',
#                           'close_approach_date_full': '1952-Sep-18 12:09',
#                           'epoch_date_close_approach': -545485860000,
#                           'miss_distance': {'astronomical': '0.4381150166',
#                                             'kilometers': '65541073.298374642',
#                                             'lunar': '170.4267414574',
#                                             'miles': '40725334.4887563796'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28395.2872220421',
#                                                 'kilometers_per_second': '7.8875797839',
#                                                 'miles_per_hour': '17643.7272186072'}},
#                          {'close_approach_date': '1953-07-22',
#                           'close_approach_date_full': '1953-Jul-22 08:41',
#                           'epoch_date_close_approach': -518973540000,
#                           'miss_distance': {'astronomical': '0.4679435943',
#                                             'kilometers': '70003364.987424141',
#                                             'lunar': '182.0300581827',
#                                             'miles': '43498073.9706935058'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78393.0745889662',
#                                                 'kilometers_per_second': '21.7758540525',
#                                                 'miles_per_hour': '48710.4079300162'}},
#                          {'close_approach_date': '1958-11-06',
#                           'close_approach_date_full': '1958-Nov-06 23:01',
#                           'epoch_date_close_approach': -351910740000,
#                           'miss_distance': {'astronomical': '0.4052163338',
#                                             'kilometers': '60619500.425689006',
#                                             'lunar': '157.6291538482',
#                                             'miles': '37667210.9127440428'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29821.8800165255',
#                                                 'kilometers_per_second': '8.2838555601',
#                                                 'miles_per_hour': '18530.1565024905'}},
#                          {'close_approach_date': '1959-06-22',
#                           'close_approach_date_full': '1959-Jun-22 11:57',
#                           'epoch_date_close_approach': -332251380000,
#                           'miss_distance': {'astronomical': '0.0488510627',
#                                             'kilometers': '7308014.927156449',
#                                             'lunar': '19.0030633903',
#                                             'miles': '4540989.9072350362'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28870.7448946033',
#                                                 'kilometers_per_second': '8.0196513596',
#                                                 'miles_per_hour': '17939.1581263162'}},
#                          {'close_approach_date': '1965-01-09',
#                           'close_approach_date_full': '1965-Jan-09 06:20',
#                           'epoch_date_close_approach': -157052400000,
#                           'miss_distance': {'astronomical': '0.0918942999',
#                                             'kilometers': '13747191.530181213',
#                                             'lunar': '35.7468826611',
#                                             'miles': '8542108.7140102194'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27010.4669596865',
#                                                 'kilometers_per_second': '7.5029074888',
#                                                 'miles_per_hour': '16783.2537617008'}},
#                          {'close_approach_date': '1965-09-11',
#                           'close_approach_date_full': '1965-Sep-11 11:07',
#                           'epoch_date_close_approach': -135867180000,
#                           'miss_distance': {'astronomical': '0.4256120866',
#                                             'kilometers': '63670661.601615542',
#                                             'lunar': '165.5631016874',
#                                             'miles': '39563114.5532447996'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27282.9217955841',
#                                                 'kilometers_per_second': '7.5785893877',
#                                                 'miles_per_hour': '16952.5466012617'}},
#                          {'close_approach_date': '1970-12-22',
#                           'close_approach_date_full': '1970-Dec-22 03:21',
#                           'epoch_date_close_approach': 30684060000,
#                           'miss_distance': {'astronomical': '0.4970942278',
#                                             'kilometers': '74364237.668174786',
#                                             'lunar': '193.3696546142',
#                                             'miles': '46207794.6030966068'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82786.0996731258',
#                                                 'kilometers_per_second': '22.9961387981',
#                                                 'miles_per_hour': '51440.0628774486'}},
#                          {'close_approach_date': '1971-11-02',
#                           'close_approach_date_full': '1971-Nov-02 20:26',
#                           'epoch_date_close_approach': 57961560000,
#                           'miss_distance': {'astronomical': '0.4161213861',
#                                             'kilometers': '62250873.022007607',
#                                             'lunar': '161.8712191929',
#                                             'miles': '38680898.8387626966'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30031.6593855286',
#                                                 'kilometers_per_second': '8.3421276071',
#                                                 'miles_per_hour': '18660.5052443025'}},
#                          {'close_approach_date': '1972-06-25',
#                           'close_approach_date_full': '1972-Jun-25 18:40',
#                           'epoch_date_close_approach': 78345600000,
#                           'miss_distance': {'astronomical': '0.0287692736',
#                                             'kilometers': '4303822.052007232',
#                                             'lunar': '11.1912474304',
#                                             'miles': '2674271.0155225216'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32284.6643092962',
#                                                 'kilometers_per_second': '8.9679623081',
#                                                 'miles_per_hour': '20060.4348870735'}},
#                          {'close_approach_date': '1978-01-06',
#                           'close_approach_date_full': '1978-Jan-06 06:31',
#                           'epoch_date_close_approach': 252916260000,
#                           'miss_distance': {'astronomical': '0.1452310516',
#                                             'kilometers': '21726255.977220092',
#                                             'lunar': '56.4948790724',
#                                             'miles': '13500069.4577055896'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22857.4894843355',
#                                                 'kilometers_per_second': '6.3493026345',
#                                                 'miles_per_hour': '14202.7550631972'}},
#                          {'close_approach_date': '1978-09-03',
#                           'close_approach_date_full': '1978-Sep-03 16:17',
#                           'epoch_date_close_approach': 273687420000,
#                           'miss_distance': {'astronomical': '0.4089770888',
#                                             'kilometers': '61182101.363280856',
#                                             'lunar': '159.0920875432',
#                                             'miles': '38016794.9249375728'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26109.746783424',
#                                                 'kilometers_per_second': '7.2527074398',
#                                                 'miles_per_hour': '16223.5812721781'}},
#                          {'close_approach_date': '1983-12-26',
#                           'close_approach_date_full': '1983-Dec-26 09:46',
#                           'epoch_date_close_approach': 441279960000,
#                           'miss_distance': {'astronomical': '0.4048345598',
#                                             'kilometers': '60562387.848467626',
#                                             'lunar': '157.4806437622',
#                                             'miles': '37631722.8028641988'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72737.749801084',
#                                                 'kilometers_per_second': '20.2049305003',
#                                                 'miles_per_hour': '45196.4090361235'}},
#                          {'close_approach_date': '1984-10-24',
#                           'close_approach_date_full': '1984-Oct-24 02:43',
#                           'epoch_date_close_approach': 467433780000,
#                           'miss_distance': {'astronomical': '0.4350098911',
#                                             'kilometers': '65076553.137491957',
#                                             'lunar': '169.2188476379',
#                                             'miles': '40436695.0451727266'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30503.8939403479',
#                                                 'kilometers_per_second': '8.4733038723',
#                                                 'miles_per_hour': '18953.9334319901'}},
#                          {'close_approach_date': '1985-07-02',
#                           'close_approach_date_full': '1985-Jul-02 21:01',
#                           'epoch_date_close_approach': 489186060000,
#                           'miss_distance': {'astronomical': '0.1010071994',
#                                             'kilometers': '15110461.884905278',
#                                             'lunar': '39.2918005666',
#                                             'miles': '9389205.6320297164'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40996.5764693123',
#                                                 'kilometers_per_second': '11.3879379081',
#                                                 'miles_per_hour': '25473.6783067235'}},
#                          {'close_approach_date': '1990-12-18',
#                           'close_approach_date_full': '1990-Dec-18 07:59',
#                           'epoch_date_close_approach': 661507140000,
#                           'miss_distance': {'astronomical': '0.243979644',
#                                             'kilometers': '36498835.06575828',
#                                             'lunar': '94.908081516',
#                                             'miles': '22679324.455613064'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23867.4018193757',
#                                                 'kilometers_per_second': '6.6298338387',
#                                                 'miles_per_hour': '14830.2753138226'}},
#                          {'close_approach_date': '1991-03-23',
#                           'close_approach_date_full': '1991-Mar-23 17:01',
#                           'epoch_date_close_approach': 669747660000,
#                           'miss_distance': {'astronomical': '0.2222873689',
#                                             'kilometers': '33253716.915344243',
#                                             'lunar': '86.4697865021',
#                                             'miles': '20662901.5397188334'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24935.883513264',
#                                                 'kilometers_per_second': '6.9266343092',
#                                                 'miles_per_hour': '15494.188286339'}},
#                          {'close_approach_date': '1991-08-17',
#                           'close_approach_date_full': '1991-Aug-17 15:32',
#                           'epoch_date_close_approach': 682443120000,
#                           'miss_distance': {'astronomical': '0.363508727',
#                                             'kilometers': '54380131.28561149',
#                                             'lunar': '141.404894803',
#                                             'miles': '33790246.706318962'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22827.8880450912',
#                                                 'kilometers_per_second': '6.3410800125',
#                                                 'miles_per_hour': '14184.3618800179'}},
#                          {'close_approach_date': '1996-12-31',
#                           'close_approach_date_full': '1996-Dec-31 18:58',
#                           'epoch_date_close_approach': 852058680000,
#                           'miss_distance': {'astronomical': '0.2617186502',
#                                             'kilometers': '39152552.609195074',
#                                             'lunar': '101.8085549278',
#                                             'miles': '24328268.0745730612'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57151.7518062629',
#                                                 'kilometers_per_second': '15.8754866129',
#                                                 'miles_per_hour': '35511.876004286'}},
#                          {'close_approach_date': '1997-10-10',
#                           'close_approach_date_full': '1997-Oct-10 21:51',
#                           'epoch_date_close_approach': 876520260000,
#                           'miss_distance': {'astronomical': '0.449991296',
#                                             'kilometers': '67317739.40013952',
#                                             'lunar': '175.046614144',
#                                             'miles': '41829303.612664576'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30320.8894958731',
#                                                 'kilometers_per_second': '8.4224693044',
#                                                 'miles_per_hour': '18840.2215870329'}},
#                          {'close_approach_date': '1998-07-11',
#                           'close_approach_date_full': '1998-Jul-11 12:30',
#                           'epoch_date_close_approach': 900160200000,
#                           'miss_distance': {'astronomical': '0.2461741872',
#                                             'kilometers': '36827134.054101264',
#                                             'lunar': '95.7617588208',
#                                             'miles': '22883319.9875708832'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55503.2983987912',
#                                                 'kilometers_per_second': '15.4175828886',
#                                                 'miles_per_hour': '34487.5911634044'}},
#                          {'close_approach_date': '2003-02-15',
#                           'close_approach_date_full': '2003-Feb-15 17:49',
#                           'epoch_date_close_approach': 1045331340000,
#                           'miss_distance': {'astronomical': '0.1392391765',
#                                             'kilometers': '20829884.224954055',
#                                             'lunar': '54.1640396585',
#                                             'miles': '12943089.878333759'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8396.5749682446',
#                                                 'kilometers_per_second': '2.3323819356',
#                                                 'miles_per_hour': '5217.3051517962'}},
#                          {'close_approach_date': '2003-11-28',
#                           'close_approach_date_full': '2003-Nov-28 15:41',
#                           'epoch_date_close_approach': 1070034060000,
#                           'miss_distance': {'astronomical': '0.3309479031',
#                                             'kilometers': '49509101.384726397',
#                                             'lunar': '128.7387343059',
#                                             'miles': '30763529.0766703986'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27266.6708909701',
#                                                 'kilometers_per_second': '7.5740752475',
#                                                 'miles_per_hour': '16942.4489211142'}},
#                          {'close_approach_date': '2004-05-03',
#                           'close_approach_date_full': '2004-May-03 17:57',
#                           'epoch_date_close_approach': 1083607020000,
#                           'miss_distance': {'astronomical': '0.1969886118',
#                                             'kilometers': '29469076.739536866',
#                                             'lunar': '76.6285699902',
#                                             'miles': '18311235.1826901108'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26142.6389995566',
#                                                 'kilometers_per_second': '7.2618441665',
#                                                 'miles_per_hour': '16244.0192161412'}},
#                          {'close_approach_date': '2010-01-06',
#                           'close_approach_date_full': '2010-Jan-06 13:52',
#                           'epoch_date_close_approach': 1262785920000,
#                           'miss_distance': {'astronomical': '0.1258552296',
#                                             'kilometers': '18827674.276520952',
#                                             'lunar': '48.9576843144',
#                                             'miles': '11698974.3067830576'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '41891.0095406426',
#                                                 'kilometers_per_second': '11.6363915391',
#                                                 'miles_per_hour': '26029.4442337399'}},
#                          {'close_approach_date': '2010-09-27',
#                           'close_approach_date_full': '2010-Sep-27 21:53',
#                           'epoch_date_close_approach': 1285624380000,
#                           'miss_distance': {'astronomical': '0.4475361831',
#                                             'kilometers': '66950459.739689997',
#                                             'lunar': '174.0915752259',
#                                             'miles': '41601086.6142240786'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29355.576394684',
#                                                 'kilometers_per_second': '8.1543267763',
#                                                 'miles_per_hour': '18240.413565908'}},
#                          {'close_approach_date': '2011-07-18',
#                           'close_approach_date_full': '2011-Jul-18 23:20',
#                           'epoch_date_close_approach': 1311031200000,
#                           'miss_distance': {'astronomical': '0.3838979119',
#                                             'kilometers': '57430309.917687653',
#                                             'lunar': '149.3362877291',
#                                             'miles': '35685539.8223814914'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69611.3586584795',
#                                                 'kilometers_per_second': '19.3364885162',
#                                                 'miles_per_hour': '43253.7911619869'}},
#                          {'close_approach_date': '2016-11-14',
#                           'close_approach_date_full': '2016-Nov-14 21:24',
#                           'epoch_date_close_approach': 1479158640000,
#                           'miss_distance': {'astronomical': '0.3797958299',
#                                             'kilometers': '56816647.187922313',
#                                             'lunar': '147.7405778311',
#                                             'miles': '35304227.4837933994'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28993.2462278438',
#                                                 'kilometers_per_second': '8.0536795077',
#                                                 'miles_per_hour': '18015.2756908511'}},
#                          {'close_approach_date': '2017-06-07',
#                           'close_approach_date_full': '2017-Jun-07 19:16',
#                           'epoch_date_close_approach': 1496862960000,
#                           'miss_distance': {'astronomical': '0.1216010783',
#                                             'kilometers': '18191262.303383221',
#                                             'lunar': '47.3028194587',
#                                             'miles': '11303526.2438456098'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24399.5198559898',
#                                                 'kilometers_per_second': '6.7776444044',
#                                                 'miles_per_hour': '15160.9127682954'}},
#                          {'close_approach_date': '2018-06-28',
#                           'close_approach_date_full': '2018-Jun-28 17:53',
#                           'epoch_date_close_approach': 1530208380000,
#                           'miss_distance': {'astronomical': '0.1299705768',
#                                             'kilometers': '19443321.451951416',
#                                             'lunar': '50.5585543752',
#                                             'miles': '12081519.7227289008'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8131.6623586873',
#                                                 'kilometers_per_second': '2.2587950996',
#                                                 'miles_per_hour': '5052.6987583743'}},
#                          {'close_approach_date': '2023-01-09',
#                           'close_approach_date_full': '2023-Jan-09 13:59',
#                           'epoch_date_close_approach': 1673272740000,
#                           'miss_distance': {'astronomical': '0.0725378046',
#                                             'kilometers': '10851501.062636202',
#                                             'lunar': '28.2172059894',
#                                             'miles': '6742810.0920635076'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32387.3337741609',
#                                                 'kilometers_per_second': '8.9964816039',
#                                                 'miles_per_hour': '20124.229699839'}},
#                          {'close_approach_date': '2023-09-19',
#                           'close_approach_date_full': '2023-Sep-19 00:06',
#                           'epoch_date_close_approach': 1695081960000,
#                           'miss_distance': {'astronomical': '0.4367402877',
#                                             'kilometers': '65335416.783107199',
#                                             'lunar': '169.8919719153',
#                                             'miles': '40597545.4558253862'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28339.6704156073',
#                                                 'kilometers_per_second': '7.872130671',
#                                                 'miles_per_hour': '17609.1690979644'}},
#                          {'close_approach_date': '2024-07-22',
#                           'close_approach_date_full': '2024-Jul-22 14:57',
#                           'epoch_date_close_approach': 1721660220000,
#                           'miss_distance': {'astronomical': '0.4698905716',
#                                             'kilometers': '70294628.644442492',
#                                             'lunar': '182.7874323524',
#                                             'miles': '43679056.8148787096'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78572.9448432724',
#                                                 'kilometers_per_second': '21.825818012',
#                                                 'miles_per_hour': '48822.1723110878'}},
#                          {'close_approach_date': '2029-11-08',
#                           'close_approach_date_full': '2029-Nov-08 09:25',
#                           'epoch_date_close_approach': 1888824300000,
#                           'miss_distance': {'astronomical': '0.4003634318',
#                                             'kilometers': '59893516.623170266',
#                                             'lunar': '155.7413749702',
#                                             'miles': '37216105.4958950308'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29746.2084370421',
#                                                 'kilometers_per_second': '8.262835677',
#                                                 'miles_per_hour': '18483.1371257832'}},
#                          {'close_approach_date': '2030-06-20',
#                           'close_approach_date_full': '2030-Jun-20 05:07',
#                           'epoch_date_close_approach': 1908162420000,
#                           'miss_distance': {'astronomical': '0.0651511359',
#                                             'kilometers': '9746471.158720533',
#                                             'lunar': '25.3437918651',
#                                             'miles': '6056176.3494000354'},
#                           'orbiting_body': 'Earth',
# ...
#                                             'kilometers': '17203886.54652773',
#                                             'lunar': '44.735341931',
#                                             'miles': '10689999.398153474'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42267.2275389226',
#                                                 'kilometers_per_second': '11.7408965386',
#                                                 'miles_per_hour': '26263.2114671711'}},
#                          {'close_approach_date': '2167-01-03',
#                           'close_approach_date_full': '2167-Jan-03 22:53',
#                           'epoch_date_close_approach': 6216994380000,
#                           'miss_distance': {'astronomical': '0.170577073',
#                                             'kilometers': '25517966.79163451',
#                                             'lunar': '66.354481397',
#                                             'miles': '15856129.305835838'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22184.4757901461',
#                                                 'kilometers_per_second': '6.1623543862',
#                                                 'miles_per_hour': '13784.5705263827'}},
#                          {'close_approach_date': '2167-09-04',
#                           'close_approach_date_full': '2167-Sep-04 01:03',
#                           'epoch_date_close_approach': 6237997380000,
#                           'miss_distance': {'astronomical': '0.4019435023',
#                                             'kilometers': '60129891.804420101',
#                                             'lunar': '156.3560223947',
#                                             'miles': '37362982.2227593538'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25646.0925257105',
#                                                 'kilometers_per_second': '7.1239145905',
#                                                 'miles_per_hour': '15935.4845474338'}},
#                          {'close_approach_date': '2172-12-24',
#                           'close_approach_date_full': '2172-Dec-24 10:53',
#                           'epoch_date_close_approach': 6405475980000,
#                           'miss_distance': {'astronomical': '0.4677830404',
#                                             'kilometers': '69979346.465963948',
#                                             'lunar': '181.9676027156',
#                                             'miles': '43483149.5535125624'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79561.3522513842',
#                                                 'kilometers_per_second': '22.1003756254',
#                                                 'miles_per_hour': '49436.3302364226'}},
#                          {'close_approach_date': '2173-11-02',
#                           'close_approach_date_full': '2173-Nov-02 13:07',
#                           'epoch_date_close_approach': 6432527220000,
#                           'miss_distance': {'astronomical': '0.4173355698',
#                                             'kilometers': '62432512.317316326',
#                                             'lunar': '162.3435366522',
#                                             'miles': '38793764.2632282588'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30265.1775908917',
#                                                 'kilometers_per_second': '8.4069937752',
#                                                 'miles_per_hour': '18805.6043758516'}},
#                          {'close_approach_date': '2174-06-28',
#                           'close_approach_date_full': '2174-Jun-28 18:01',
#                           'epoch_date_close_approach': 6453108060000,
#                           'miss_distance': {'astronomical': '0.0341017101',
#                                             'kilometers': '5101543.194317487',
#                                             'lunar': '13.2655652289',
#                                             'miles': '3169951.9483238406'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32787.1826710645',
#                                                 'kilometers_per_second': '9.107550742',
#                                                 'miles_per_hour': '20372.6802546956'}},
#                          {'close_approach_date': '2179-01-22',
#                           'close_approach_date_full': '2179-Jan-22 18:07',
#                           'epoch_date_close_approach': 6597310020000,
#                           'miss_distance': {'astronomical': '0.126583576',
#                                             'kilometers': '18936633.34658312',
#                                             'lunar': '49.241011064',
#                                             'miles': '11766678.333442256'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8504.8224604997',
#                                                 'kilometers_per_second': '2.3624506835',
#                                                 'miles_per_hour': '5284.5659338589'}},
#                          {'close_approach_date': '2180-01-11',
#                           'close_approach_date_full': '2180-Jan-11 07:19',
#                           'epoch_date_close_approach': 6627856740000,
#                           'miss_distance': {'astronomical': '0.110548927',
#                                             'kilometers': '16537884.00998549',
#                                             'lunar': '43.003532603',
#                                             'miles': '10276164.611720162'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25028.3818160533',
#                                                 'kilometers_per_second': '6.9523282822',
#                                                 'miles_per_hour': '15551.663134536'}},
#                          {'close_approach_date': '2180-09-11',
#                           'close_approach_date_full': '2180-Sep-11 17:17',
#                           'epoch_date_close_approach': 6648974220000,
#                           'miss_distance': {'astronomical': '0.4212758767',
#                                             'kilometers': '63021973.836702629',
#                                             'lunar': '163.8763160363',
#                                             'miles': '39160038.6670051202'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27151.3548561541',
#                                                 'kilometers_per_second': '7.5420430156',
#                                                 'miles_per_hour': '16870.7960215919'}},
#                          {'close_approach_date': '2186-11-06',
#                           'close_approach_date_full': '2186-Nov-06 01:18',
#                           'epoch_date_close_approach': 6843057480000,
#                           'miss_distance': {'astronomical': '0.4105163461',
#                                             'kilometers': '61412370.976742807',
#                                             'lunar': '159.6908586329',
#                                             'miles': '38159877.8279004566'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30109.5294765189',
#                                                 'kilometers_per_second': '8.3637581879',
#                                                 'miles_per_hour': '18708.8906905626'}},
#                          {'close_approach_date': '2187-06-26',
#                           'close_approach_date_full': '2187-Jun-26 02:37',
#                           'epoch_date_close_approach': 6863107020000,
#                           'miss_distance': {'astronomical': '0.0402625746',
#                                             'kilometers': '6023195.400876102',
#                                             'lunar': '15.6621415194',
#                                             'miles': '3742640.0735781276'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30165.7683544833',
#                                                 'kilometers_per_second': '8.3793800985',
#                                                 'miles_per_hour': '18743.8353422622'}},
#                          {'close_approach_date': '2193-01-10',
#                           'close_approach_date_full': '2193-Jan-10 21:55',
#                           'epoch_date_close_approach': 7038136500000,
#                           'miss_distance': {'astronomical': '0.0818004303',
#                                             'kilometers': '12237170.137963461',
#                                             'lunar': '31.8203673867',
#                                             'miles': '7603824.9296833218'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28591.3991559581',
#                                                 'kilometers_per_second': '7.9420553211',
#                                                 'miles_per_hour': '17765.5835477674'}},
#                          {'close_approach_date': '2193-09-16',
#                           'close_approach_date_full': '2193-Sep-16 23:42',
#                           'epoch_date_close_approach': 7059656520000,
#                           'miss_distance': {'astronomical': '0.4305048144',
#                                             'kilometers': '64402603.258985328',
#                                             'lunar': '167.4663728016',
#                                             'miles': '40017922.0094324064'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27939.6890015819',
#                                                 'kilometers_per_second': '7.7610247227',
#                                                 'miles_per_hour': '17360.6362021218'}},
#                          {'close_approach_date': '2194-07-26',
#                           'close_approach_date_full': '2194-Jul-26 01:00',
#                           'epoch_date_close_approach': 7086618000000,
#                           'miss_distance': {'astronomical': '0.4918178356',
#                                             'kilometers': '73574900.633770172',
#                                             'lunar': '191.3171380484',
#                                             'miles': '45717323.3133734936'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81015.1603798306',
#                                                 'kilometers_per_second': '22.5042112166',
#                                                 'miles_per_hour': '50339.6700704564'}},
#                          {'close_approach_date': '2199-11-12',
#                           'close_approach_date_full': '2199-Nov-12 07:47',
#                           'epoch_date_close_approach': 7253826420000,
#                           'miss_distance': {'astronomical': '0.3929980081',
#                                             'kilometers': '58791664.926002747',
#                                             'lunar': '152.8762251509',
#                                             'miles': '36531446.5993300286'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29592.9016898757',
#                                                 'kilometers_per_second': '8.2202504694',
#                                                 'miles_per_hour': '18387.8782750231'}},
#                          {'close_approach_date': '2200-06-17',
#                           'close_approach_date_full': '2200-Jun-17 14:20',
#                           'epoch_date_close_approach': 7272598800000,
#                           'miss_distance': {'astronomical': '0.0918688139',
#                                             'kilometers': '13743378.878866393',
#                                             'lunar': '35.7369686071',
#                                             'miles': '8539739.6423385034'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25707.429425271',
#                                                 'kilometers_per_second': '7.1409526181',
#                                                 'miles_per_hour': '15973.5969114969'}}],
#  'designation': '226554',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 2301.5744618737,
#                                  'estimated_diameter_min': 1029.2953904054},
#                         'kilometers': {'estimated_diameter_max': 0.7015198735,
#                                        'estimated_diameter_min': 0.313729225},
#                         'meters': {'estimated_diameter_max': 701.5198735305,
#                                    'estimated_diameter_min': 313.7292249562},
#                         'miles': {'estimated_diameter_max': 0.4359041053,
#                                   'estimated_diameter_min': 0.1949422422}},
#  'id': '2226554',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=GT5a6VBQVVTnT8H1jSPfja2DfDMaC1d0UsYeWsYW'},
#  'name': '226554 (2003 WR21)',
#  'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2226554',
#  'neo_reference_id': '2226554',
#  'orbital_data': {'aphelion_distance': '1.410933079850529',
#                   'ascending_node_longitude': '85.77596539565366',
#                   'data_arc_in_days': 11771,
#                   'eccentricity': '.2616161183742341',
#                   'epoch_osculation': '2460000.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '1990-10-24',
#                   'inclination': '9.264882989275051',
#                   'jupiter_tisserand_invariant': '5.536',
#                   'last_observation_date': '2023-01-15',
#                   'mean_anomaly': '343.0403429047203',
#                   'mean_motion': '.8333650704864628',
#                   'minimum_orbit_intersection': '.0302692',
#                   'observations_used': 456,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2023-01-24 04:52:55',
#                   'orbit_id': '105',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '431.983548086382',
#                   'perihelion_argument': '108.0903748997368',
#                   'perihelion_distance': '.825774361187416',
#                   'perihelion_time': '2460020.850813462076',
#                   'semi_major_axis': '1.118353720518973'}}

# %% [markdown]
# ## Lab 3 - Exercise 1
# ### Define an Asteroid Class
#
# Using what we learned in the textbook, define a simple `Asteroid` class with some basic state variables for a single NEO.  Your Asteroid class should define at least 4 "state variables”:
#
# *   `id`, `name`, `estimated_diameter`, and `is_potentially_hazardous`
# *   Provide an `__init__(self, ...)` method to initialize a new Asteroid object with specific data values and a little code to test your class.
# *   Add a `__str__(self)` method that returns a nicely formatted string representation of the object, plus a little code to test it.

# %%
@dataclass
class Asteroid:
    """ Represents an asteroid. """
    id: int
    name: str
    estimated_diameter: float # Units: meters
    is_potentially_hazardous: bool

    # Replace __init__ and __str__ methods by using @dataclass
    # def __init__(self, id, name, diameter, hazardous):
    #     self.id = id
    #     self.name = name
    #     self.diameter = diameter
    #     self.hazardous = hazardous
    
    # def __str__(self):
    #     return f'Asteroid ID: {self.id}, Name: {self.name}, Est. Diameter (m): {self.diameter:.2f}, Hazardous (T/F): {self.hazardous}'

test_asteroid = Asteroid('1234567', '1234567 2023 (BB31)', 555.55, True)
print(test_asteroid)
# Out:
# Asteroid(id='1234567', name='1234567 2023 (BB31)', estimated_diameter=555.55, is_potentially_hazardous=True)

# %% [markdown]
# ## Lab 3 - Exercise 2
# ### Factory method: Asteroid.from_NEO
#
# We want to be able to construct Asteroid objects easily from the NEO API.
#
# Define a `“@classmethod”: from_NEO(cls, neo_id)` that takes the id for a single NEO, fetches the NEO record from the API, then constructs and returns an Asteroid object representing that NEO. This kind of method is sometimes called a “factory” – it constructs an object from raw materials.

# %%
@dataclass
class Asteroid:
    """ Represents an asteroid. """
    id: int
    name: str
    estimated_diameter: float # Units: meters
    is_potentially_hazardous: bool

    @classmethod
    def from_NEO(cls, neo_id):
        url = f'https://api.nasa.gov/neo/rest/v1/neo/{neo_id}/?api_key={API_KEY}'
        response = requests.request("GET", url, headers={}, data={})
        data = json.loads(response.text)

        # Pull the desired attributes out of the data
        name = data['name']
        # Get max and min estimated diameter in meters
        max_diameter = float(data['estimated_diameter']['meters']['estimated_diameter_max'])
        min_diameter = float(data['estimated_diameter']['meters']['estimated_diameter_min'])
        # Average the max and min diameter to get estimated diameter in meters
        estimated_diameter = (max_diameter + min_diameter) / 2
        is_potentially_hazardous = data['is_potentially_hazardous_asteroid']

        return cls(neo_id, name, estimated_diameter, is_potentially_hazardous)

test_asteroid_from_id = Asteroid.from_NEO('2226554')
print(test_asteroid_from_id)
# Out:
# Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True)

# %% [markdown]
# ## Lab 3 - Exercise 3
# ### Define a CloseApproach class
#
# Each NEO comes with a list of “`close_approach_data`”, where each record in this list represents a single “close approach” to another orbiting body.
#
# *   Develop a class named “**CloseApproach**” to represent a single close approach record. State variables are **asteroid** (Asteroid object),  **orbiting body** (`str`), **approach date** (`datetime` object!),  **miss distance** (`float` choose units, document it, and be consistent!),  and **relative velocity** (ditto).
# *   Define a Factory class method to construct a `CloseApproach` object from one close approach data record (a dictionary object).
#
# Remember to parse the date/time string into a `datetime` object.

# %%
@dataclass
class CloseApproach:
    """ Represents a single close approach record. """
    asteroid: Asteroid
    orbiting_body: str
    approach_date: datetime
    miss_distance: float     # Units: kilometers
    relative_velocity: float # Units: kilometers per hour

    @classmethod
    # Method must take an Asteroid object and a close approach data record
    def from_record(cls, asteroid, record):
        # Pull the desired attributes from the supplied record
        body = record['orbiting_body']
        # Get date of approach and convert to a datetime object
        date = datetime.datetime.strptime(record['close_approach_date'], '%Y-%m-%d').date()
        # Get miss distance in kilometers
        distance = float(record['miss_distance']['kilometers'])
        # Get relative velocity in kilometers per hour
        velocity = float(record['relative_velocity']['kilometers_per_hour'])

        return cls(asteroid, body, date, distance, velocity)

test_approach = {
    'close_approach_date': '1900-10-30',
    'close_approach_date_full': '1900-Oct-30 21:14',
    'epoch_date_close_approach': -2182819560000,
    'miss_distance': {'astronomical': '0.4183489529',
                    'kilometers': '62584112.270570323',
                    'lunar': '162.7377426781',
                    'miles': '38887964.1060755374'},
    'orbiting_body': 'Earth',
    'relative_velocity': {'kilometers_per_hour': '30027.9637577316',
                        'kilometers_per_second': '8.3411010438',
                        'miles_per_hour': '18658.2089249083'}
}

# Use test asteroid from Exercise 2 and sample data record to test from_record factory class method
CloseApproach.from_record(test_asteroid_from_id, test_approach)
# Out:
# CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1900, 10, 30), miss_distance=62584112.27057032, relative_velocity=30027.9637577316)

# %% [markdown]
# ## Lab 3 - Exercise 4
# ### Add list of close approaches to Asteroid
#
# Every Asteroid should have a list of “close approaches”.  Add a new state variable to your Asteroid class, initially an empty list.  In the factory method, use a list comprehension to build a list of `CloseApproach` objects for the Asteroid from the NEO data record.
#
# Extend your test code to demonstrate this new feature.

# %%
from operator import attrgetter

# Test list comprehension before adding it into the Asteroid class factory method
close_approaches = [CloseApproach.from_record(test_asteroid_from_id, approach) for approach in data['close_approach_data']]
num_approaches = len(close_approaches)

print(f"Close approaches found: {num_approaches}")

sorted_close_approaches = sorted(close_approaches, key=attrgetter('miss_distance'))
pprint(sorted_close_approaches)
# Out:
# Close approaches found: 130
# [CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1972, 6, 25), miss_distance=4303822.052007232, relative_velocity=32284.6643092962),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1901, 6, 26), miss_distance=4619550.017178589, relative_velocity=33429.0363049198),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2102, 6, 28), miss_distance=4775418.551175805, relative_velocity=32339.6089540488),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2174, 6, 28), miss_distance=5101543.194317487, relative_velocity=32787.1826710645),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2187, 6, 26), miss_distance=6023195.400876102, relative_velocity=30165.7683544833),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2115, 6, 25), miss_distance=6062602.23243491, relative_velocity=30020.8163413929),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1914, 6, 28), miss_distance=6558812.787224359, relative_velocity=35203.0524829447),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1959, 6, 22), miss_distance=7308014.927156449, relative_velocity=28870.7448946033),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2043, 6, 20), miss_distance=9676177.094299417, relative_velocity=27548.0035900371),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2030, 6, 20), miss_distance=9746471.158720532, relative_velocity=27470.8063203169),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2049, 1, 9), miss_distance=10799716.353715723, relative_velocity=31393.8953367567),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2023, 1, 9), miss_distance=10851501.062636202, relative_velocity=32387.3337741609),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1952, 1, 9), miss_distance=10964938.075660653, relative_velocity=33228.6655783573),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2036, 1, 10), miss_distance=11567287.765702983, relative_velocity=29452.8051168836),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2121, 1, 10), miss_distance=11751125.700907093, relative_velocity=29234.8145985177),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2193, 1, 10), miss_distance=12237170.13796346, relative_velocity=28591.3991559581),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2200, 6, 17), miss_distance=13743378.878866393, relative_velocity=25707.429425271),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1965, 1, 9), miss_distance=13747191.530181212, relative_velocity=27010.4669596865),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2134, 1, 8), miss_distance=13937607.64276411, relative_velocity=37456.5915457045),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2089, 7, 3), miss_distance=14077045.049830515, relative_velocity=40157.9431708),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2128, 6, 14), miss_distance=15012131.474230444, relative_velocity=25221.2250642586),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1985, 7, 2), miss_distance=15110461.884905279, relative_velocity=40996.5764693123),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2062, 1, 7), miss_distance=15329435.438002463, relative_velocity=38912.7137934686),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2108, 1, 11), miss_distance=15692715.763955195, relative_velocity=25627.8005445431),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2180, 1, 11), miss_distance=16537884.00998549, relative_velocity=25028.3818160533),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2056, 6, 9), miss_distance=17172993.569107216, relative_velocity=24542.9392637258),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2161, 7, 5), miss_distance=17203886.54652773, relative_velocity=42267.2275389226),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2017, 6, 7), miss_distance=18191262.30338322, relative_velocity=24399.5198559898),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1907, 1, 8), miss_distance=18554355.766636536, relative_velocity=24041.8524771157),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2010, 1, 6), miss_distance=18827674.276520953, relative_velocity=41891.0095406426),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(2179, 1, 22), miss_distance=18936633.34658312, relative_velocity=8504.8224604997),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(2121, 3, 25), miss_distance=19037916.116101764, relative_velocity=8375.1561589628),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(2077, 7, 21), miss_distance=19262523.719460383, relative_velocity=8362.6232137757),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(2018, 6, 28), miss_distance=19443321.451951414, relative_velocity=8131.6623586873),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(1909, 8, 6), miss_distance=19705248.981622554, relative_velocity=7812.3404746925),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(2091, 9, 9), miss_distance=19852813.008740757, relative_velocity=8163.5396563474),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(1924, 12, 19), miss_distance=20369911.884198733, relative_velocity=7522.0862587508),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(2033, 11, 19), miss_distance=20545063.089965977, relative_velocity=8443.6829542503),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(2003, 2, 15), miss_distance=20829884.224954054, relative_velocity=8396.5749682446),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Venus', approach_date=datetime.date(2063, 6, 2), miss_distance=20987993.076813243, relative_velocity=8597.1100007631),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1946, 5, 31), miss_distance=21644058.126047123, relative_velocity=24131.1433453815),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1978, 1, 6), miss_distance=21726255.977220092, relative_velocity=22857.4894843355),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2095, 1, 5), miss_distance=22975855.78168485, relative_velocity=22590.3555661361),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2167, 1, 3), miss_distance=25517966.79163451, relative_velocity=22184.4757901461),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1927, 7, 7), miss_distance=26134395.43641828, relative_velocity=48367.5389747381),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1939, 1, 4), miss_distance=26516893.044912063, relative_velocity=47802.6926864899),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2141, 5, 11), miss_distance=28008580.021378353, relative_velocity=25890.3459571172),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1919, 12, 30), miss_distance=28129444.837924473, relative_velocity=22319.4650472732),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2069, 5, 7), miss_distance=28865950.77118732, relative_velocity=26071.6348848171),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2004, 5, 3), miss_distance=29469076.739536867, relative_velocity=26142.6389995566),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1920, 2, 20), miss_distance=30173823.0599585, relative_velocity=18956.388545382),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2147, 1, 4), miss_distance=32398673.923352264, relative_velocity=52182.3010628315),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1933, 4, 15), miss_distance=32614752.084474538, relative_velocity=26552.3338547447),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1991, 3, 23), miss_distance=33253716.915344242, relative_velocity=24935.883513264),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2154, 4, 2), miss_distance=33468836.842270017, relative_velocity=26234.2514633813),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2082, 3, 26), miss_distance=33486766.790260356, relative_velocity=25465.2144235802),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2075, 1, 2), miss_distance=34717909.254403874, relative_velocity=53887.0019950159),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2076, 7, 11), miss_distance=36160880.61201146, relative_velocity=55078.9745846461),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1990, 12, 18), miss_distance=36498835.06575828, relative_velocity=23867.4018193757),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1998, 7, 11), miss_distance=36827134.054101266, relative_velocity=55503.2983987912),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2081, 12, 15), miss_distance=37758941.727024615, relative_velocity=24162.1739645087),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2148, 7, 13), miss_distance=38175142.1199724, relative_velocity=56407.0486933184),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1996, 12, 31), miss_distance=39152552.609195076, relative_velocity=57151.7518062629),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2153, 12, 14), miss_distance=39754164.826617666, relative_velocity=24765.0827140506),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1932, 12, 6), miss_distance=44125751.90129494, relative_velocity=25801.9540329191),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1933, 7, 30), miss_distance=47548058.93006349, relative_velocity=19585.8848031947),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2003, 11, 28), miss_distance=49509101.3847264, relative_velocity=27266.6708909701),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1940, 7, 15), miss_distance=50045433.37018007, relative_velocity=64571.4313637087),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1925, 12, 28), miss_distance=50333086.153490655, relative_velocity=65215.3650106068),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2068, 11, 25), miss_distance=50441218.74020044, relative_velocity=27572.4242068632),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2140, 11, 25), miss_distance=51375134.63606655, relative_velocity=27755.2996288071),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2154, 8, 16), miss_distance=52660058.97061462, relative_velocity=22062.9003220283),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2159, 12, 29), miss_distance=53892799.08017059, relative_velocity=67914.2894045814),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2082, 8, 17), miss_distance=53922606.7848834, relative_velocity=22685.0340905273),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1991, 8, 17), miss_distance=54380131.28561149, relative_velocity=22827.8880450912),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1945, 11, 18), miss_distance=55164628.00613332, relative_velocity=28578.7009045491),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2016, 11, 14), miss_distance=56816647.187922314, relative_velocity=28993.2462278438),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2055, 11, 14), miss_distance=57315906.322905555, relative_velocity=29184.3258611513),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2087, 12, 27), miss_distance=57405855.871948525, relative_velocity=70398.3276547924),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2011, 7, 18), miss_distance=57430309.917687654, relative_velocity=69611.3586584795),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2063, 7, 19), miss_distance=57701921.77019175, relative_velocity=69795.8331256753),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2127, 11, 13), miss_distance=58234688.46440865, relative_velocity=29394.2395195616),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1920, 8, 27), miss_distance=58677987.58400014, relative_velocity=24779.592022273),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2199, 11, 12), miss_distance=58791664.92600275, relative_velocity=29592.9016898757),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2135, 7, 21), miss_distance=59015531.07743828, relative_velocity=70808.0512560296),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2029, 11, 8), miss_distance=59893516.623170264, relative_velocity=29746.2084370421),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2042, 11, 8), miss_distance=59914995.72078721, relative_velocity=29729.3612693709),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2167, 9, 4), miss_distance=60129891.8044201, relative_velocity=25646.0925257105),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1983, 12, 26), miss_distance=60562387.848467626, relative_velocity=72737.749801084),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1958, 11, 6), miss_distance=60619500.425689004, relative_velocity=29821.8800165255),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2095, 9, 4), miss_distance=60894842.261724964, relative_velocity=26025.1302100317),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1978, 9, 3), miss_distance=61182101.363280855, relative_velocity=26109.746783424),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2114, 11, 6), miss_distance=61265394.25590244, relative_velocity=30002.4918244656),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2186, 11, 6), miss_distance=61412370.976742804, relative_velocity=30109.5294765189),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1907, 9, 6), miss_distance=62042216.3364171, relative_velocity=26520.1966604789),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2101, 11, 3), miss_distance=62204975.019191206, relative_velocity=30113.7199236434),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1971, 11, 2), miss_distance=62250873.02200761, relative_velocity=30031.6593855286),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2173, 11, 2), miss_distance=62432512.31731632, relative_velocity=30265.1775908917),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1900, 10, 30), miss_distance=62584112.27057032, relative_velocity=30027.9637577316),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2180, 9, 11), miss_distance=63021973.83670263, relative_velocity=27151.3548561541),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2108, 9, 11), miss_distance=63175635.87691628, relative_velocity=27196.2789896979),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1913, 10, 29), miss_distance=63287012.53831637, relative_velocity=30216.1966422462),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1965, 9, 11), miss_distance=63670661.60161554, relative_velocity=27282.9217955841),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2193, 9, 16), miss_distance=64402603.258985326, relative_velocity=27939.6890015819),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2121, 9, 17), miss_distance=64477069.338724576, relative_velocity=27975.6034163716),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2036, 9, 15), miss_distance=64522305.8646392, relative_velocity=27897.7376740915),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2088, 10, 24), miss_distance=64652041.43096207, relative_velocity=30404.7748721795),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2049, 9, 18), miss_distance=65013535.00483488, relative_velocity=28200.4259868873),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1984, 10, 24), miss_distance=65076553.13749196, relative_velocity=30503.8939403479),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2160, 10, 23), miss_distance=65151764.738216355, relative_velocity=30521.5562246282),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2023, 9, 19), miss_distance=65335416.7831072, relative_velocity=28339.6704156073),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1952, 9, 18), miss_distance=65541073.298374645, relative_velocity=28395.2872220421),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2134, 9, 26), miss_distance=66124994.954318464, relative_velocity=29075.8133351568),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2062, 9, 26), miss_distance=66314770.87777649, relative_velocity=29153.4043577398),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1926, 10, 17), miss_distance=66556486.80770383, relative_velocity=30428.213228163),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2075, 10, 10), miss_distance=66766896.16697947, relative_velocity=30236.9667012519),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2147, 10, 10), miss_distance=66838337.69194285, relative_velocity=30153.0114537888),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2010, 9, 27), miss_distance=66950459.73969, relative_velocity=29355.576394684),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1997, 10, 10), miss_distance=67317739.40013953, relative_velocity=30320.8894958731),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1939, 10, 2), miss_distance=67439053.48900883, relative_velocity=29767.9781480216),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1912, 12, 22), miss_distance=69136710.53787808, relative_velocity=78889.9632007097),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2050, 7, 23), miss_distance=69772300.73999633, relative_velocity=78277.7805713888),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2172, 12, 24), miss_distance=69979346.46596394, relative_velocity=79561.3522513842),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1953, 7, 22), miss_distance=70003364.98742414, relative_velocity=78393.0745889662),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2024, 7, 22), miss_distance=70294628.6444425, relative_velocity=78572.9448432724),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2100, 12, 23), miss_distance=71538234.78032613, relative_velocity=80742.0177811836),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2122, 7, 25), miss_distance=72788536.76727308, relative_velocity=80350.8671727601),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2194, 7, 26), miss_distance=73574900.63377017, relative_velocity=81015.1603798306),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(2037, 7, 24), miss_distance=73871041.28606904, relative_velocity=81117.5455384567),
#  CloseApproach(asteroid=Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True), orbiting_body='Earth', approach_date=datetime.date(1970, 12, 22), miss_distance=74364237.66817479, relative_velocity=82786.0996731258)]

# %%
@dataclass
class Asteroid:
    """ Represents an asteroid. """
    id: int
    name: str
    estimated_diameter: float # Units: meters
    is_potentially_hazardous: bool
    close_approaches: list # Add attribute to store list of close approaches

    @classmethod
    def from_NEO(cls, neo_id):
        url = f'https://api.nasa.gov/neo/rest/v1/neo/{neo_id}/?api_key={API_KEY}'
        response = requests.request("GET", url, headers={}, data={})
        data = json.loads(response.text)

        # Pull the desired attributes out of the data
        name = data['name']
        # Get max and min estimated diameter in meters
        max_diameter = float(data['estimated_diameter']['meters']['estimated_diameter_max'])
        min_diameter = float(data['estimated_diameter']['meters']['estimated_diameter_min'])
        # Average the max and min diameter to get estimated diameter in meters
        estimated_diameter = (max_diameter + min_diameter) / 2
        is_potentially_hazardous = data['is_potentially_hazardous_asteroid']
        close_approaches = [] # Initially set close_approaches to an empty list

        # Generate Asteroid object
        asteroid = cls(neo_id, name, estimated_diameter, is_potentially_hazardous, close_approaches)
        # Populate close_approaches list with CloseApproach objects using list comprehension and from_record factory method
        asteroid.close_approaches = [CloseApproach.from_record(asteroid, approach) for approach in data['close_approach_data']]

        return asteroid

test_asteroid_from_id = Asteroid.from_NEO('2226554')
print(test_asteroid_from_id)

# Check that the number of close approaches matches the total found in the test comprehension above
assert len(test_asteroid_from_id.close_approaches) == num_approaches
print(len(test_asteroid_from_id.close_approaches), "close approaches associated with Asteroid", str(test_asteroid_from_id.id))
# Out:
# Asteroid(id='2226554', name='226554 (2003 WR21)', estimated_diameter=507.62454924335003, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1900, 10, 30), miss_distance=62584112.27057032, relative_velocity=30027.9637577316), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 6, 26), miss_distance=4619550.017178589, relative_velocity=33429.0363049198), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1907, 1, 8), miss_distance=18554355.766636536, relative_velocity=24041.8524771157), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1907, 9, 6), miss_distance=62042216.3364171, relative_velocity=26520.1966604789), CloseApproach(asteroid=..., orbiting_body='Venus', approach_date=datetime.date(1909, 8, 6), miss_distance=19705248.981622554, relative_velocity=7812.3404746925), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 12, 22), miss_distance=69136710.53787808, relative_velocity=78889.9632007097), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 10, 29), miss_distance=63287012.53831637, relative_velocity=30216.1966422462), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1914, 6, 28), miss_distance=6558812.787224359, relative_velocity=35203.0524829447), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1919, 12, 30), miss_distance=28129444.837924473, relative_velocity=22319.4650472732), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1920, 2, 20), miss_distance=30173823.0599585, relative_velocity=18956.388545382), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1920, 8, 27), miss_distance=58677987.58400014, relative_velocity=24779.592022273), CloseApproach(asteroid=..., orbiting_body='Venus', approach_date=datetime.date(1924, 12, 19), miss_distance=20369911.884198733, relative_velocity=7522.0862587508), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1925, 12, 28), miss_distance=50333086.153490655, relative_velocity=65215.3650106068), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1926, 10, 17), miss_distance=66556486.80770383, relative_velocity=30428.213228163), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1927, 7, 7), miss_distance=26134395.43641828, relative_velocity=48367.5389747381), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1932, 12, 6), miss_distance=44125751.90129494, relative_velocity=25801.9540329191), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 4, 15), miss_distance=32614752.084474538, relative_velocity=26552.3338547447), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 7, 30), miss_distance=47548058.93006349, relative_velocity=19585.8848031947), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1939, 1, 4), miss_distance=26516893.044912063, relative_velocity=47802.6926864899), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1939, 10, 2), miss_distance=67439053.48900883, relative_velocity=29767.9781480216), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1940, 7, 15), miss_distance=50045433.37018007, relative_velocity=64571.4313637087), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 11, 18), miss_distance=55164628.00613332, relative_velocity=28578.7009045491), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1946, 5, 31), miss_distance=21644058.126047123, relative_velocity=24131.1433453815), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1952, 1, 9), miss_distance=109 ...
# 130 close approaches associated with Asteroid 2226554

# %% [markdown]
# ## Lab 3 - Optional
# ### Take your skills to the next level!
#
# With this data structure in place, we can now start answering all kinds of interesting questions about a single Asteroid or a set of Asteroids.
#
# Here’s a couple ideas to try:
#
# *   Add a  method to the `Asteroid` class, `closest_earth_approach`, that returns the `CloseApproach` object that represents the closest approach the Asteroid makes to Earth.
#
# *   Write a function named `most_dangerous_approach`, that takes a date range and returns a single “potentially hazardous” Asteroid object that makes the closest approach to Earth in within that range. Your algorithm will ultimately need to:
#
#    *   grab the list of NEO’s for the given date range
#    *   use a list comprehension to build the list of Asteroid objects for the NEOs returned
#    *   use a list comprehension to **filter** potentially hazardous Asteroids only
#    *   use a list comprehension to **map** each Asteroid to its `closest_earth_approach`
#    *   apply Python’s `min` function to identify the Asteroid with the `closest_earth_approach`
#
#    You may want to *decompose* some of these steps into smaller functions.
#
# *   Add a method to the `Asteroid` class, `estimated_mass`, that computes an estimate of the Asteroid’s mass based on its diameter.  This is a model – state your assumptions.
#
# *   Add a method to the `CloseApproach` class, `impact_force`,  that estimates the force of impact if the Asteroid hit the orbiting object.  Again, this is a model, state your assumptions.

# %%
# Add a closest_earth_approach method

@dataclass
class Asteroid:
    """ Represents an asteroid. """
    id: int
    name: str
    estimated_diameter: float # Units: meters
    is_potentially_hazardous: bool
    close_approaches: list # Add attribute to store list of close approaches

    @classmethod
    def from_NEO(cls, neo_id):
        url = f'https://api.nasa.gov/neo/rest/v1/neo/{neo_id}/?api_key={API_KEY}'
        response = requests.request("GET", url, headers={}, data={})
        data = json.loads(response.text)

        # Pull the desired attributes out of the data
        name = data['name']
        # Get max and min estimated diameter in meters
        max_diameter = float(data['estimated_diameter']['meters']['estimated_diameter_max'])
        min_diameter = float(data['estimated_diameter']['meters']['estimated_diameter_min'])
        # Average the max and min diameter to get estimated diameter in meters
        estimated_diameter = (max_diameter + min_diameter) / 2
        is_potentially_hazardous = data['is_potentially_hazardous_asteroid']
        close_approaches = [] # Initially set close_approaches to an empty list

        # Generate Asteroid object
        asteroid = cls(neo_id, name, estimated_diameter, is_potentially_hazardous, close_approaches)
        # Populate close_approaches list with CloseApproach objects using list comprehension and from_record factory method
        asteroid.close_approaches = [CloseApproach.from_record(asteroid, approach) for approach in data['close_approach_data']]

        return asteroid
    
    def closest_earth_approach(self):
        # Filter the approaches by orbiting body
        earth_approaches = [approach for approach in self.close_approaches if approach.orbiting_body == 'Earth']
        
        # Find the closest approach to Earth
        closest_to_earth = earth_approaches[0]
        for approach in earth_approaches:
            if approach.miss_distance < closest_to_earth.miss_distance:
                closest_to_earth = approach
        return closest_to_earth

test_asteroid = Asteroid.from_NEO('2226554')
closest_earth_approach = test_asteroid.closest_earth_approach()

# Check that the closest_earth_approach method returns the expected result
expected = sorted_close_approaches[0].miss_distance
result = closest_earth_approach.miss_distance
assert result == expected

print(f"The closest Asteroid {test_asteroid.id} will come to Earth is {closest_earth_approach.miss_distance:.0f} kilometers.")
# Out:
# The closest Asteroid 2226554 will come to Earth is 4303822 kilometers.

# %%
# Write a function most_dangerous_approach

# %%
# Add an estimated_mass method

# %%
# Add an impact_force method
