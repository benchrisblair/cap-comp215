# %% [markdown]
# COMP 215 - LAB 3 (NEO)
# ----------------
# #### Name: Ben Blair
# #### Date: 23/01/2023
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from dataclasses import dataclass
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# ## Fetch Complete Data for One Asteroid (from Lab 2)
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the asteroid with id '3014110'...

# %%
API_KEY = 'GT5a6VBQVVTnT8H1jSPfja2DfDMaC1d0UsYeWsYW'

id = '3014110'
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

pprint(data)
# Out:
# {'absolute_magnitude_h': 21.3,
#  'close_approach_data': [{'close_approach_date': '1901-01-23',
#                           'close_approach_date_full': '1901-Jan-23 11:09',
#                           'epoch_date_close_approach': -2175511860000,
#                           'miss_distance': {'astronomical': '0.3113584635',
#                                             'kilometers': '46578562.946072745',
#                                             'lunar': '121.1184423015',
#                                             'miles': '28942576.929564081'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '94290.7642054826',
#                                                 'kilometers_per_second': '26.191878946',
#                                                 'miles_per_hour': '58588.6140142345'}},
#                          {'close_approach_date': '1908-09-20',
#                           'close_approach_date_full': '1908-Sep-20 08:53',
#                           'epoch_date_close_approach': -1933859220000,
#                           'miss_distance': {'astronomical': '0.257620095',
#                                             'kilometers': '38539417.48119765',
#                                             'lunar': '100.214216955',
#                                             'miles': '23947283.57252157'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '103801.0019940824',
#                                                 'kilometers_per_second': '28.833611665',
#                                                 'miles_per_hour': '64497.9059334897'}},
#                          {'close_approach_date': '1912-03-20',
#                           'close_approach_date_full': '1912-Mar-20 00:53',
#                           'epoch_date_close_approach': -1823555220000,
#                           'miss_distance': {'astronomical': '0.4300463882',
#                                             'kilometers': '64334023.675913134',
#                                             'lunar': '167.2880450098',
#                                             'miles': '39975308.6325198892'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '77694.2599215679',
#                                                 'kilometers_per_second': '21.5817388671',
#                                                 'miles_per_hour': '48276.1916718209'}},
#                          {'close_approach_date': '1913-09-06',
#                           'close_approach_date_full': '1913-Sep-06 03:54',
#                           'epoch_date_close_approach': -1777320360000,
#                           'miss_distance': {'astronomical': '0.1444007648',
#                                             'kilometers': '21602046.840450976',
#                                             'lunar': '56.1718975072',
#                                             'miles': '13422889.4790004288'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65813.6151496408',
#                                                 'kilometers_per_second': '18.2815597638',
#                                                 'miles_per_hour': '40894.0210356198'}},
#                          {'close_approach_date': '1917-02-05',
#                           'close_approach_date_full': '1917-Feb-05 12:50',
#                           'epoch_date_close_approach': -1669461000000,
#                           'miss_distance': {'astronomical': '0.2667700852',
#                                             'kilometers': '39908236.525638524',
#                                             'lunar': '103.7735631428',
#                                             'miles': '24797828.2864546712'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78525.9998454341',
#                                                 'kilometers_per_second': '21.8127777348',
#                                                 'miles_per_hour': '48793.0025150699'}},
#                          {'close_approach_date': '1922-01-10',
#                           'close_approach_date_full': '1922-Jan-10 19:06',
#                           'epoch_date_close_approach': -1513918440000,
#                           'miss_distance': {'astronomical': '0.4626225217',
#                                             'kilometers': '69207343.860348779',
#                                             'lunar': '179.9601609413',
#                                             'miles': '43003449.3783759902'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '116891.1009352116',
#                                                 'kilometers_per_second': '32.4697502598',
#                                                 'miles_per_hour': '72631.5843561041'}},
#                          {'close_approach_date': '1924-09-27',
#                           'close_approach_date_full': '1924-Sep-27 11:55',
#                           'epoch_date_close_approach': -1428321900000,
#                           'miss_distance': {'astronomical': '0.4165517097',
#                                             'kilometers': '62315248.515978339',
#                                             'lunar': '162.0386150733',
#                                             'miles': '38720899.9158415182'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '121081.2081500725',
#                                                 'kilometers_per_second': '33.6336689306',
#                                                 'miles_per_hour': '75235.1540308048'}},
#                          {'close_approach_date': '1928-04-05',
#                           'close_approach_date_full': '1928-Apr-05 17:14',
#                           'epoch_date_close_approach': -1317192360000,
#                           'miss_distance': {'astronomical': '0.4929454081',
#                                             'kilometers': '73743583.078040747',
#                                             'lunar': '191.7557637509',
#                                             'miles': '45822137.7239344286'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '85300.0041370266',
#                                                 'kilometers_per_second': '23.6944455936',
#                                                 'miles_per_hour': '53002.1053483652'}},
#                          {'close_approach_date': '1929-09-10',
#                           'close_approach_date_full': '1929-Sep-10 21:30',
#                           'epoch_date_close_approach': -1271989800000,
#                           'miss_distance': {'astronomical': '0.0258889581',
#                                             'kilometers': '3872932.988279247',
#                                             'lunar': '10.0708047009',
#                                             'miles': '2406528.9666857286'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79060.1565419183',
#                                                 'kilometers_per_second': '21.961154595',
#                                                 'miles_per_hour': '49124.9067135047'}},
#                          {'close_approach_date': '1933-02-19',
#                           'close_approach_date_full': '1933-Feb-19 07:42',
#                           'epoch_date_close_approach': -1163348280000,
#                           'miss_distance': {'astronomical': '0.3065809121',
#                                             'kilometers': '45863851.432817227',
#                                             'lunar': '119.2599748069',
#                                             'miles': '28498475.7884706526'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71449.6847325052',
#                                                 'kilometers_per_second': '19.8471346479',
#                                                 'miles_per_hour': '44396.055493928'}},
#                          {'close_approach_date': '1934-09-08',
#                           'close_approach_date_full': '1934-Sep-08 00:29',
#                           'epoch_date_close_approach': -1114471860000,
#                           'miss_distance': {'astronomical': '0.395055981',
#                                             'kilometers': '59099533.28836047',
#                                             'lunar': '153.676776609',
#                                             'miles': '36722747.128975686'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '51910.4125940515',
#                                                 'kilometers_per_second': '14.4195590539',
#                                                 'miles_per_hour': '32255.1116476761'}},
#                          {'close_approach_date': '1938-01-19',
#                           'close_approach_date_full': '1938-Jan-19 07:37',
#                           'epoch_date_close_approach': -1008260580000,
#                           'miss_distance': {'astronomical': '0.3542740432',
#                                             'kilometers': '52998642.259007984',
#                                             'lunar': '137.8126028048',
#                                             'miles': '32931829.2305348192'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '101697.2229386336',
#                                                 'kilometers_per_second': '28.2492285941',
#                                                 'miles_per_hour': '63190.6994420638'}},
#                          {'close_approach_date': '1945-09-16',
#                           'close_approach_date_full': '1945-Sep-16 14:36',
#                           'epoch_date_close_approach': -766574640000,
#                           'miss_distance': {'astronomical': '0.1564577979',
#                                             'kilometers': '23405753.310730473',
#                                             'lunar': '60.8620833831',
#                                             'miles': '14543660.7087796074'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '93379.0505732244',
#                                                 'kilometers_per_second': '25.9386251592',
#                                                 'miles_per_hour': '58022.1106186794'}},
#                          {'close_approach_date': '1949-03-07',
#                           'close_approach_date_full': '1949-Mar-07 08:27',
#                           'epoch_date_close_approach': -657041580000,
#                           'miss_distance': {'astronomical': '0.3748822728',
#                                             'kilometers': '56081589.511638936',
#                                             'lunar': '145.8292041192',
#                                             'miles': '34847483.8232358768'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72609.3928212782',
#                                                 'kilometers_per_second': '20.1692757837',
#                                                 'miles_per_hour': '45116.6530005326'}},
#                          {'close_approach_date': '1950-09-04',
#                           'close_approach_date_full': '1950-Sep-04 19:23',
#                           'epoch_date_close_approach': -609827820000,
#                           'miss_distance': {'astronomical': '0.2621097693',
#                                             'kilometers': '39211063.193471391',
#                                             'lunar': '101.9607002577',
#                                             'miles': '24364624.8657555558'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57126.750569879',
#                                                 'kilometers_per_second': '15.868541825',
#                                                 'miles_per_hour': '35496.3412082673'}},
#                          {'close_approach_date': '1954-01-27',
#                           'close_approach_date_full': '1954-Jan-27 15:49',
#                           'epoch_date_close_approach': -502618260000,
#                           'miss_distance': {'astronomical': '0.2846457206',
#                                             'kilometers': '42582393.506375122',
#                                             'lunar': '110.7271853134',
#                                             'miles': '26459472.3828238036'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '88974.3391963448',
#                                                 'kilometers_per_second': '24.7150942212',
#                                                 'miles_per_hour': '55285.1942634177'}},
#                          {'close_approach_date': '1961-09-21',
#                           'close_approach_date_full': '1961-Sep-21 15:45',
#                           'epoch_date_close_approach': -261216900000,
#                           'miss_distance': {'astronomical': '0.2737575521',
#                                             'kilometers': '40953546.690574027',
#                                             'lunar': '106.4916877669',
#                                             'miles': '25447353.9040424926'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '105587.2277098758',
#                                                 'kilometers_per_second': '29.329785475',
#                                                 'miles_per_hour': '65607.7971289503'}},
#                          {'close_approach_date': '1965-03-20',
#                           'close_approach_date_full': '1965-Mar-20 08:42',
#                           'epoch_date_close_approach': -150995880000,
#                           'miss_distance': {'astronomical': '0.429556821',
#                                             'kilometers': '64260785.46557127',
#                                             'lunar': '167.097603369',
#                                             'miles': '39929800.518852726'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '77498.7494092013',
#                                                 'kilometers_per_second': '21.5274303914',
#                                                 'miles_per_hour': '48154.7090426229'}},
#                          {'close_approach_date': '1966-09-06',
#                           'close_approach_date_full': '1966-Sep-06 09:27',
#                           'epoch_date_close_approach': -104769180000,
#                           'miss_distance': {'astronomical': '0.1533080368',
#                                             'kilometers': '22934555.759161616',
#                                             'lunar': '59.6368263152',
#                                             'miles': '14250872.1270216608'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64971.627399698',
#                                                 'kilometers_per_second': '18.0476742777',
#                                                 'miles_per_hour': '40370.8425917735'}},
#                          {'close_approach_date': '1970-02-03',
#                           'close_approach_date_full': '1970-Feb-03 21:04',
#                           'epoch_date_close_approach': 2927040000,
#                           'miss_distance': {'astronomical': '0.2645472548',
#                                             'kilometers': '39575705.832427276',
#                                             'lunar': '102.9088821172',
#                                             'miles': '24591203.2950213688'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '80459.9418453926',
#                                                 'kilometers_per_second': '22.3499838459',
#                                                 'miles_per_hour': '49994.6788649886'}},
#                          {'close_approach_date': '1977-09-25',
#                           'close_approach_date_full': '1977-Sep-25 08:56',
#                           'epoch_date_close_approach': 244025760000,
#                           'miss_distance': {'astronomical': '0.3560950085',
#                                             'kilometers': '53271054.789231895',
#                                             'lunar': '138.5209583065',
#                                             'miles': '33101098.527694351'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '114465.6840307061',
#                                                 'kilometers_per_second': '31.7960233419',
#                                                 'miles_per_hour': '71124.5246134129'}},
#                          {'close_approach_date': '1981-03-28',
#                           'close_approach_date_full': '1981-Mar-28 22:55',
#                           'epoch_date_close_approach': 354668100000,
#                           'miss_distance': {'astronomical': '0.4633162819',
#                                             'kilometers': '69311128.908559553',
#                                             'lunar': '180.2300336591',
#                                             'miles': '43067938.4169377114'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81338.3477573296',
#                                                 'kilometers_per_second': '22.5939854881',
#                                                 'miles_per_hour': '50540.4861384362'}},
#                          {'close_approach_date': '1982-09-08',
#                           'close_approach_date_full': '1982-Sep-08 12:56',
#                           'epoch_date_close_approach': 400337760000,
#                           'miss_distance': {'astronomical': '0.0802990138',
#                                             'kilometers': '12012561.427580606',
#                                             'lunar': '31.2363163682',
#                                             'miles': '7464259.5487841228'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71265.7537453242',
#                                                 'kilometers_per_second': '19.796042707',
#                                                 'miles_per_hour': '44281.7679313655'}},
#                          {'close_approach_date': '1986-02-09',
#                           'close_approach_date_full': '1986-Feb-09 03:15',
#                           'epoch_date_close_approach': 508302900000,
#                           'miss_distance': {'astronomical': '0.2695700968',
#                                             'kilometers': '40327112.296973816',
#                                             'lunar': '104.8627676552',
#                                             'miles': '25058105.6215420208'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '75973.5382237812',
#                                                 'kilometers_per_second': '21.1037606177',
#                                                 'miles_per_hour': '47207.0021257712'}},
#                          {'close_approach_date': '1991-01-11',
#                           'close_approach_date_full': '1991-Jan-11 10:25',
#                           'epoch_date_close_approach': 663589500000,
#                           'miss_distance': {'astronomical': '0.4607531083',
#                                             'kilometers': '68927683.597559321',
#                                             'lunar': '179.2329591287',
#                                             'miles': '42829676.5490317898'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '116923.9855842245',
#                                                 'kilometers_per_second': '32.4788848845',
#                                                 'miles_per_hour': '72652.0175981533'}},
#                          {'close_approach_date': '1993-09-27',
#                           'close_approach_date_full': '1993-Sep-27 07:37',
#                           'epoch_date_close_approach': 749115420000,
#                           'miss_distance': {'astronomical': '0.3978070015',
#                                             'kilometers': '59511080.095486805',
#                                             'lunar': '154.7469235835',
#                                             'miles': '36978470.456875709'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '119060.8872653974',
#                                                 'kilometers_per_second': '33.0724686848',
#                                                 'miles_per_hour': '73979.805201102'}},
#                          {'close_approach_date': '1997-04-01',
#                           'close_approach_date_full': '1997-Apr-01 19:24',
#                           'epoch_date_close_approach': 859922640000,
#                           'miss_distance': {'astronomical': '0.4775703132',
#                                             'kilometers': '71443501.629952884',
#                                             'lunar': '185.7748518348',
#                                             'miles': '44392933.3851784392'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '83040.15651188',
#                                                 'kilometers_per_second': '23.0667101422',
#                                                 'miles_per_hour': '51597.9239170624'}},
#                          {'close_approach_date': '1998-09-09',
#                           'close_approach_date_full': '1998-Sep-09 14:50',
#                           'epoch_date_close_approach': 905352600000,
#                           'miss_distance': {'astronomical': '0.0503150473',
#                                             'kilometers': '7527023.905029251',
#                                             'lunar': '19.5725533997',
#                                             'miles': '4677075.7756996238'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '74080.8448393198',
#                                                 'kilometers_per_second': '20.5780124554',
#                                                 'miles_per_hour': '46030.9560614095'}},
#                          {'close_approach_date': '2002-02-10',
#                           'close_approach_date_full': '2002-Feb-10 21:43',
#                           'epoch_date_close_approach': 1013377380000,
#                           'miss_distance': {'astronomical': '0.2737009673',
#                                             'kilometers': '40945081.725019651',
#                                             'lunar': '106.4696762797',
#                                             'miles': '25442094.0183511438'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '74776.8011274875',
#                                                 'kilometers_per_second': '20.7713336465',
#                                                 'miles_per_hour': '46463.3962339102'}},
#                          {'close_approach_date': '2003-09-14',
#                           'close_approach_date_full': '2003-Sep-14 12:53',
#                           'epoch_date_close_approach': 1063543980000,
#                           'miss_distance': {'astronomical': '0.4892222347',
#                                             'kilometers': '73186604.267760089',
#                                             'lunar': '190.3074492983',
#                                             'miles': '45476047.1396596682'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '51486.8813699821',
#                                                 'kilometers_per_second': '14.3019114917',
#                                                 'miles_per_hour': '31991.9458156981'}},
#                          {'close_approach_date': '2007-01-11',
#                           'close_approach_date_full': '2007-Jan-11 15:44',
#                           'epoch_date_close_approach': 1168530240000,
#                           'miss_distance': {'astronomical': '0.4576287184',
#                                             'kilometers': '68460281.523469808',
#                                             'lunar': '178.0175714576',
#                                             'miles': '42539246.3676190304'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '116551.4493731742',
#                                                 'kilometers_per_second': '32.3754026037',
#                                                 'miles_per_hour': '72420.5380841259'}},
#                          {'close_approach_date': '2009-09-27',
#                           'close_approach_date_full': '2009-Sep-27 04:06',
#                           'epoch_date_close_approach': 1254024360000,
#                           'miss_distance': {'astronomical': '0.3927802081',
#                                             'kilometers': '58759082.509916747',
#                                             'lunar': '152.7915009509',
#                                             'miles': '36511200.8247832286'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '118522.4622057122',
#                                                 'kilometers_per_second': '32.9229061683',
#                                                 'miles_per_hour': '73645.248807766'}},
#                          {'close_approach_date': '2013-03-31',
#                           'close_approach_date_full': '2013-Mar-31 02:04',
#                           'epoch_date_close_approach': 1364695440000,
#                           'miss_distance': {'astronomical': '0.4713704316',
#                                             'kilometers': '70516012.548340692',
#                                             'lunar': '183.3630978924',
#                                             'miles': '43816618.3939458696'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82251.4398170357',
#                                                 'kilometers_per_second': '22.8476221714',
#                                                 'miles_per_hour': '51107.846035202'}},
#                          {'close_approach_date': '2014-09-08',
#                           'close_approach_date_full': '2014-Sep-08 23:17',
#                           'epoch_date_close_approach': 1410218220000,
#                           'miss_distance': {'astronomical': '0.0703304159',
#                                             'kilometers': '10521280.414854133',
#                                             'lunar': '27.3585317851',
#                                             'miles': '6537620.4962997154'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72157.6927717664',
#                                                 'kilometers_per_second': '20.0438035477',
#                                                 'miles_per_hour': '44835.984155879'}},
#                          {'close_approach_date': '2018-02-08',
#                           'close_approach_date_full': '2018-Feb-08 06:06',
#                           'epoch_date_close_approach': 1518069960000,
#                           'miss_distance': {'astronomical': '0.2673213221',
#                                             'kilometers': '39990700.391743927',
#                                             'lunar': '103.9879942969',
#                                             'miles': '24849068.9567911126'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '76634.8761773506',
#                                                 'kilometers_per_second': '21.2874656048',
#                                                 'miles_per_hour': '47617.931811421'}},
#                          {'close_approach_date': '2023-01-09',
#                           'close_approach_date_full': '2023-Jan-09 07:10',
#                           'epoch_date_close_approach': 1673248200000,
#                           'miss_distance': {'astronomical': '0.4928732055',
#                                             'kilometers': '73732781.722872285',
#                                             'lunar': '191.7276769395',
#                                             'miles': '45815426.073056133'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '121198.8588141982',
#                                                 'kilometers_per_second': '33.6663496706',
#                                                 'miles_per_hour': '75308.2575781889'}},
#                          {'close_approach_date': '2025-09-25',
#                           'close_approach_date_full': '2025-Sep-25 01:34',
#                           'epoch_date_close_approach': 1758764040000,
#                           'miss_distance': {'astronomical': '0.3435138813',
#                                             'kilometers': '51388944.957912831',
#                                             'lunar': '133.6268998257',
#                                             'miles': '31931609.7084298278'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '113175.8175721921',
#                                                 'kilometers_per_second': '31.4377271034',
#                                                 'miles_per_hour': '70323.0517575657'}},
#                          {'close_approach_date': '2029-03-24',
#                           'close_approach_date_full': '2029-Mar-24 13:33',
#                           'epoch_date_close_approach': 1869053580000,
#                           'miss_distance': {'astronomical': '0.4462370571',
#                                             'kilometers': '66756113.257228377',
#                                             'lunar': '173.5862152119',
#                                             'miles': '41480325.3097985226'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79170.6793709016',
#                                                 'kilometers_per_second': '21.9918553808',
#                                                 'miles_per_hour': '49193.5813013249'}},
#                          {'close_approach_date': '2030-09-07',
#                           'close_approach_date_full': '2030-Sep-07 03:20',
#                           'epoch_date_close_approach': 1914981600000,
#                           'miss_distance': {'astronomical': '0.1335638513',
#                                             'kilometers': '19980867.663476731',
#                                             'lunar': '51.9563381557',
#                                             'miles': '12415535.4500556478'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66647.0680471397',
#                                                 'kilometers_per_second': '18.5130744575',
#                                                 'miles_per_hour': '41411.8962540685'}},
#                          {'close_approach_date': '2034-02-02',
#                           'close_approach_date_full': '2034-Feb-02 20:11',
#                           'epoch_date_close_approach': 2022523860000,
#                           'miss_distance': {'astronomical': '0.2638620562',
#                                             'kilometers': '39473201.581340294',
#                                             'lunar': '102.6423398618',
#                                             'miles': '24527510.1068882972'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81611.878468545',
#                                                 'kilometers_per_second': '22.6699662413',
#                                                 'miles_per_hour': '50710.4474850801'}},
#                          {'close_approach_date': '2041-09-21',
#                           'close_approach_date_full': '2041-Sep-21 14:54',
#                           'epoch_date_close_approach': 2263388040000,
#                           'miss_distance': {'astronomical': '0.2625930418',
#                                             'kilometers': '39283359.730100966',
#                                             'lunar': '102.1486932602',
#                                             'miles': '24409547.8505106908'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '104500.6217384558',
#                                                 'kilometers_per_second': '29.0279504829',
#                                                 'miles_per_hour': '64932.6224352089'}},
#                          {'close_approach_date': '2045-03-14',
#                           'close_approach_date_full': '2045-Mar-14 14:46',
#                           'epoch_date_close_approach': 2373115560000,
#                           'miss_distance': {'astronomical': '0.4052123619',
#                                             'kilometers': '60618906.237909153',
#                                             'lunar': '157.6276087791',
#                                             'miles': '37666841.7015781914'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '74705.5124746247',
#                                                 'kilometers_per_second': '20.751531243',
#                                                 'miles_per_hour': '46419.1002373578'}},
#                          {'close_approach_date': '2046-09-05',
#                           'close_approach_date_full': '2046-Sep-05 08:20',
#                           'epoch_date_close_approach': 2419748400000,
#                           'miss_distance': {'astronomical': '0.224286571',
#                                             'kilometers': '33552793.29120377',
#                                             'lunar': '87.247476119',
#                                             'miles': '20848738.982281226'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '59615.3480920639',
#                                                 'kilometers_per_second': '16.5598189145',
#                                                 'miles_per_hour': '37042.6589297605'}},
#                          {'close_approach_date': '2050-01-27',
#                           'close_approach_date_full': '2050-Jan-27 07:55',
#                           'epoch_date_close_approach': 2526882900000,
#                           'miss_distance': {'astronomical': '0.2856349132',
#                                             'kilometers': '42730374.612354884',
#                                             'lunar': '111.1119812348',
#                                             'miles': '26551423.5782460392'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '89725.0173961738',
#                                                 'kilometers_per_second': '24.9236159434',
#                                                 'miles_per_hour': '55751.6365037503'}},
#                          {'close_approach_date': '2057-09-17',
#                           'close_approach_date_full': '2057-Sep-17 07:31',
#                           'epoch_date_close_approach': 2767937460000,
#                           'miss_distance': {'astronomical': '0.1583579283',
#                                             'kilometers': '23690008.771292721',
#                                             'lunar': '61.6012341087',
#                                             'miles': '14720288.8616167098'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '93649.0727893464',
#                                                 'kilometers_per_second': '26.0136313304',
#                                                 'miles_per_hour': '58189.8919229136'}},
#                          {'close_approach_date': '2061-03-01',
#                           'close_approach_date_full': '2061-Mar-01 23:34',
#                           'epoch_date_close_approach': 2876945640000,
#                           'miss_distance': {'astronomical': '0.350255646',
#                                             'kilometers': '52397498.59707402',
#                                             'lunar': '136.249446294',
#                                             'miles': '32558295.879980676'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '70980.1281040248',
#                                                 'kilometers_per_second': '19.7167022511',
#                                                 'miles_per_hour': '44104.2912655259'}},
#                          {'close_approach_date': '2062-09-05',
#                           'close_approach_date_full': '2062-Sep-05 20:14',
#                           'epoch_date_close_approach': 2924712840000,
#                           'miss_distance': {'astronomical': '0.3332632734',
#                                             'kilometers': '49855475.849867658',
#                                             'lunar': '129.6394133526',
#                                             'miles': '30978756.1890953604'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '53399.8046730812',
#                                                 'kilometers_per_second': '14.8332790759',
#                                                 'miles_per_hour': '33180.5619647821'}},
#                          {'close_approach_date': '2066-01-20',
#                           'close_approach_date_full': '2066-Jan-20 08:06',
#                           'epoch_date_close_approach': 3031200360000,
#                           'miss_distance': {'astronomical': '0.3446523026',
#                                             'kilometers': '51559250.359555462',
#                                             'lunar': '134.0697457114',
#                                             'miles': '32037432.5779388956'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '100714.5945039697',
#                                                 'kilometers_per_second': '27.9762762511',
#                                                 'miles_per_hour': '62580.1323460916'}},
#                          {'close_approach_date': '2073-09-12',
#                           'close_approach_date_full': '2073-Sep-12 15:42',
#                           'epoch_date_close_approach': 3272456520000,
#                           'miss_distance': {'astronomical': '0.0406202714',
#                                             'kilometers': '6076706.080261918',
#                                             'lunar': '15.8012855746',
#                                             'miles': '3775890.0679257484'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81834.2061805397',
#                                                 'kilometers_per_second': '22.731723939',
#                                                 'miles_per_hour': '50848.5932792359'}},
#                          {'close_approach_date': '2077-02-17',
#                           'close_approach_date_full': '2077-Feb-17 10:47',
#                           'epoch_date_close_approach': 3380784420000,
#                           'miss_distance': {'astronomical': '0.2954824398',
#                                             'kilometers': '44203543.616483226',
#                                             'lunar': '114.9426690822',
#                                             'miles': '27466808.3504554788'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71610.8367817285',
#                                                 'kilometers_per_second': '19.891899106',
#                                                 'miles_per_hour': '44496.1891102913'}},
#                          {'close_approach_date': '2078-09-10',
#                           'close_approach_date_full': '2078-Sep-10 17:38',
#                           'epoch_date_close_approach': 3430057080000,
#                           'miss_distance': {'astronomical': '0.4373563756',
#                                             'kilometers': '65427582.220679972',
#                                             'lunar': '170.1316301084',
#                                             'miles': '40654814.4031367336'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '51198.7402737439',
#                                                 'kilometers_per_second': '14.2218722983',
#                                                 'miles_per_hour': '31812.9061439827'}},
#                          {'close_approach_date': '2082-01-14',
#                           'close_approach_date_full': '2082-Jan-14 10:02',
#                           'epoch_date_close_approach': 3535610520000,
#                           'miss_distance': {'astronomical': '0.4186025247',
#                                             'kilometers': '62622046.071742389',
#                                             'lunar': '162.8363821083',
#                                             'miles': '38911535.0771234082'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '111467.8777786679',
#                                                 'kilometers_per_second': '30.963299383',
#                                                 'miles_per_hour': '69261.8043897506'}},
#                          {'close_approach_date': '2084-09-28',
#                           'close_approach_date_full': '2084-Sep-28 22:01',
#                           'epoch_date_close_approach': 3621016860000,
#                           'miss_distance': {'astronomical': '0.4267069479',
#                                             'kilometers': '63834450.520040973',
#                                             'lunar': '165.9890027331',
#                                             'miles': '39664888.2678445074'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '122359.4548375122',
#                                                 'kilometers_per_second': '33.9887374549',
#                                                 'miles_per_hour': '76029.4068127864'}},
#                          {'close_approach_date': '2088-04-02',
#                           'close_approach_date_full': '2088-Apr-02 08:48',
#                           'epoch_date_close_approach': 3731734080000,
#                           'miss_distance': {'astronomical': '0.4800586157',
#                                             'kilometers': '71815746.383868559',
#                                             'lunar': '186.7428015073',
#                                             'miles': '44624235.5496377542'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '83080.4091588302',
#                                                 'kilometers_per_second': '23.077891433',
#                                                 'miles_per_hour': '51622.9353464965'}},
#                          {'close_approach_date': '2089-09-09',
#                           'close_approach_date_full': '2089-Sep-09 11:13',
#                           'epoch_date_close_approach': 3777102780000,
#                           'miss_distance': {'astronomical': '0.0578002397',
#                                             'kilometers': '8646792.744609439',
#                                             'lunar': '22.4842932433',
#                                             'miles': '5372867.8683066982'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '73319.7676644414',
#                                                 'kilometers_per_second': '20.366602129',
#                                                 'miles_per_hour': '45558.0523023858'}},
#                          {'close_approach_date': '2093-02-07',
#                           'close_approach_date_full': '2093-Feb-07 18:34',
#                           'epoch_date_close_approach': 3884870040000,
#                           'miss_distance': {'astronomical': '0.2641839705',
#                                             'kilometers': '39521359.274942835',
#                                             'lunar': '102.7675645245',
#                                             'miles': '24557433.910107723'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '76878.25837312',
#                                                 'kilometers_per_second': '21.3550717703',
#                                                 'miles_per_hour': '47769.1600430089'}},
#                          {'close_approach_date': '2100-09-24',
#                           'close_approach_date_full': '2100-Sep-24 00:05',
#                           'epoch_date_close_approach': 4125427500000,
#                           'miss_distance': {'astronomical': '0.2921168807',
#                                             'kilometers': '43700063.143764109',
#                                             'lunar': '113.6334665923',
#                                             'miles': '27153960.0916743442'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '107664.9938741696',
#                                                 'kilometers_per_second': '29.9069427428',
#                                                 'miles_per_hour': '66898.840221425'}},
#                          {'close_approach_date': '2104-03-17',
#                           'close_approach_date_full': '2104-Mar-17 07:54',
#                           'epoch_date_close_approach': 4235183640000,
#                           'miss_distance': {'astronomical': '0.412598378',
#                                             'kilometers': '61723838.51425486',
#                                             'lunar': '160.500769042',
#                                             'miles': '38353414.781282668'},
# ...
#                                             'kilometers': '14679458.318967595',
#                                             'lunar': '38.1710600965',
#                                             'miles': '9121392.434819011'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '82692.7258256482',
#                                                 'kilometers_per_second': '22.9702016182',
#                                                 'miles_per_hour': '51382.0439998312'}},
#                          {'close_approach_date': '2182-12-17',
#                           'close_approach_date_full': '2182-Dec-17 18:14',
#                           'epoch_date_close_approach': 6720430440000,
#                           'miss_distance': {'astronomical': '0.101208517',
#                                             'kilometers': '15140578.56905879',
#                                             'lunar': '39.370113113',
#                                             'miles': '9407919.271799702'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '81196.5871834286',
#                                                 'kilometers_per_second': '22.554607551',
#                                                 'miles_per_hour': '50452.4016307254'}},
#                          {'close_approach_date': '2184-03-10',
#                           'close_approach_date_full': '2184-Mar-10 20:12',
#                           'epoch_date_close_approach': 6759231120000,
#                           'miss_distance': {'astronomical': '0.1051751492',
#                                             'kilometers': '15733978.297252204',
#                                             'lunar': '40.9131330388',
#                                             'miles': '9776640.7650562552'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '79726.571994838',
#                                                 'kilometers_per_second': '22.1462699986',
#                                                 'miles_per_hour': '49538.9913597925'}},
#                          {'close_approach_date': '2185-06-02',
#                           'close_approach_date_full': '2185-Jun-02 22:10',
#                           'epoch_date_close_approach': 6798031800000,
#                           'miss_distance': {'astronomical': '0.1101534608',
#                                             'kilometers': '16478723.108808496',
#                                             'lunar': '42.8496962512',
#                                             'miles': '10239403.7323534048'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '78250.382428432',
#                                                 'kilometers_per_second': '21.7362173412',
#                                                 'miles_per_hour': '48621.7445705998'}},
#                          {'close_approach_date': '2186-08-25',
#                           'close_approach_date_full': '2186-Aug-25 23:54',
#                           'epoch_date_close_approach': 6836831640000,
#                           'miss_distance': {'astronomical': '0.1160768857',
#                                             'kilometers': '17364854.856953459',
#                                             'lunar': '45.1539085373',
#                                             'miles': '10790020.4682133742'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '76746.9118250423',
#                                                 'kilometers_per_second': '21.3185866181',
#                                                 'miles_per_hour': '47687.5464059547'}},
#                          {'close_approach_date': '2186-09-14',
#                           'close_approach_date_full': '2186-Sep-14 10:40',
#                           'epoch_date_close_approach': 6838512000000,
#                           'miss_distance': {'astronomical': '0.0382636145',
#                                             'kilometers': '5724155.227701115',
#                                             'lunar': '14.8845460405',
#                                             'miles': '3556825.126320787'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81893.3714548952',
#                                                 'kilometers_per_second': '22.7481587375',
#                                                 'miles_per_hour': '50885.3562798487'}},
#                          {'close_approach_date': '2187-11-18',
#                           'close_approach_date_full': '2187-Nov-18 05:10',
#                           'epoch_date_close_approach': 6875644200000,
#                           'miss_distance': {'astronomical': '0.1195452552',
#                                             'kilometers': '17883715.546526424',
#                                             'lunar': '46.5031042728',
#                                             'miles': '11112425.5505916912'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '75946.8536214098',
#                                                 'kilometers_per_second': '21.0963482282',
#                                                 'miles_per_hour': '47190.4213515921'}},
#                          {'close_approach_date': '2189-02-09',
#                           'close_approach_date_full': '2189-Feb-09 09:59',
#                           'epoch_date_close_approach': 6914455140000,
#                           'miss_distance': {'astronomical': '0.1240290307',
#                                             'kilometers': '18554478.810884609',
#                                             'lunar': '48.2472929423',
#                                             'miles': '11529218.5161172442'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '74994.1990342628',
#                                                 'kilometers_per_second': '20.831721954',
#                                                 'miles_per_hour': '46598.4788388174'}},
#                          {'close_approach_date': '2190-02-18',
#                           'close_approach_date_full': '2190-Feb-18 20:42',
#                           'epoch_date_close_approach': 6946807320000,
#                           'miss_distance': {'astronomical': '0.2919210317',
#                                             'kilometers': '43670764.550522479',
#                                             'lunar': '113.5572813313',
#                                             'miles': '27135754.7900250502'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71417.4994723046',
#                                                 'kilometers_per_second': '19.8381942979',
#                                                 'miles_per_hour': '44376.0568248884'}},
#                          {'close_approach_date': '2190-05-04',
#                           'close_approach_date_full': '2190-May-04 15:08',
#                           'epoch_date_close_approach': 6953267280000,
#                           'miss_distance': {'astronomical': '0.1283639068',
#                                             'kilometers': '19202967.042158516',
#                                             'lunar': '49.9335597452',
#                                             'miles': '11932170.4179028808'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '74110.8755764703',
#                                                 'kilometers_per_second': '20.5863543268',
#                                                 'miles_per_hour': '46049.6159936129'}},
#                          {'close_approach_date': '2191-07-27',
#                           'close_approach_date_full': '2191-Jul-27 20:04',
#                           'epoch_date_close_approach': 6992078640000,
#                           'miss_distance': {'astronomical': '0.1328958841',
#                                             'kilometers': '19880941.193126867',
#                                             'lunar': '51.6964989149',
#                                             'miles': '12353444.0205980846'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '73214.7289917307',
#                                                 'kilometers_per_second': '20.3374247199',
#                                                 'miles_per_hour': '45492.7853560007'}},
#                          {'close_approach_date': '2191-09-12',
#                           'close_approach_date_full': '2191-Sep-12 13:00',
#                           'epoch_date_close_approach': 6996114000000,
#                           'miss_distance': {'astronomical': '0.4443656421',
#                                             'kilometers': '66476153.559342327',
#                                             'lunar': '172.8582347769',
#                                             'miles': '41306366.4201130326'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '50873.221078258',
#                                                 'kilometers_per_second': '14.1314502995',
#                                                 'miles_per_hour': '31610.6411749876'}},
#                          {'close_approach_date': '2192-10-18',
#                           'close_approach_date_full': '2192-Oct-18 23:39',
#                           'epoch_date_close_approach': 7030885140000,
#                           'miss_distance': {'astronomical': '0.1392558892',
#                                             'kilometers': '20832384.409276004',
#                                             'lunar': '54.1705408988',
#                                             'miles': '12944643.4208326952'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '72060.3220217418',
#                                                 'kilometers_per_second': '20.0167561172',
#                                                 'miles_per_hour': '44775.481758454'}},
#                          {'close_approach_date': '2194-01-11',
#                           'close_approach_date_full': '2194-Jan-11 02:56',
#                           'epoch_date_close_approach': 7069690560000,
#                           'miss_distance': {'astronomical': '0.1469469925',
#                                             'kilometers': '21982957.080905975',
#                                             'lunar': '57.1623800825',
#                                             'miles': '13659576.127113455'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '70761.0106158638',
#                                                 'kilometers_per_second': '19.6558362822',
#                                                 'miles_per_hour': '43968.1401796183'}},
#                          {'close_approach_date': '2195-01-15',
#                           'close_approach_date_full': '2195-Jan-15 11:49',
#                           'epoch_date_close_approach': 7101604140000,
#                           'miss_distance': {'astronomical': '0.4266406488',
#                                             'kilometers': '63824532.315898056',
#                                             'lunar': '165.9632123832',
#                                             'miles': '39658725.3815669328'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '113027.105676325',
#                                                 'kilometers_per_second': '31.3964182434',
#                                                 'miles_per_hour': '70230.6479687143'}},
#                          {'close_approach_date': '2197-09-29',
#                           'close_approach_date_full': '2197-Sep-29 16:56',
#                           'epoch_date_close_approach': 7186985760000,
#                           'miss_distance': {'astronomical': '0.4026436659',
#                                             'kilometers': '60234634.787631633',
#                                             'lunar': '156.6283860351',
#                                             'miles': '37428066.4945292154'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '119730.3285163338',
#                                                 'kilometers_per_second': '33.2584245879',
#                                                 'miles_per_hour': '74395.7699606075'}}],
#  'designation': '1998 SU4',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 1071.581062656,
#                                  'estimated_diameter_min': 479.2256199},
#                         'kilometers': {'estimated_diameter_max': 0.3266178974,
#                                        'estimated_diameter_min': 0.1460679643},
#                         'meters': {'estimated_diameter_max': 326.6178974458,
#                                    'estimated_diameter_min': 146.0679642714},
#                         'miles': {'estimated_diameter_max': 0.2029508896,
#                                   'estimated_diameter_min': 0.090762397}},
#  'id': '3014110',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3014110?api_key=GT5a6VBQVVTnT8H1jSPfja2DfDMaC1d0UsYeWsYW'},
#  'name': '(1998 SU4)',
#  'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3014110',
#  'neo_reference_id': '3014110',
#  'orbital_data': {'aphelion_distance': '1.814193786759056',
#                   'ascending_node_longitude': '350.6014016674613',
#                   'data_arc_in_days': 5855,
#                   'eccentricity': '.5804514855373714',
#                   'epoch_osculation': '2460000.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '1998-09-19',
#                   'inclination': '23.15293909382605',
#                   'jupiter_tisserand_invariant': '5.236',
#                   'last_observation_date': '2014-09-30',
#                   'mean_anomaly': '4.429082703457727',
#                   'mean_motion': '.80140180187961',
#                   'minimum_orbit_intersection': '.0196733',
#                   'observations_used': 97,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2021-04-14 20:48:31',
#                   'orbit_id': '27',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '449.2128657006448',
#                   'perihelion_argument': '241.8148025017122',
#                   'perihelion_distance': '.4815980212915527',
#                   'perihelion_time': '2459994.973330739874',
#                   'semi_major_axis': '1.147895904025305'}}

# %% [markdown]
# ## Lab 3 - Exercise 1
# ### Define an Asteroid Class
#
# Using what we learned in the textbook, define a simple `Asteroid` class with some basic state variables for a single NEO.  Your Asteroid class should define at least 4 "state variables”:
#
# *   `id`, `name`, `estimated_diameter`, and `is_potentially_hazardous`
# *   Provide an `__init__(self, ...)` method to initialize a new Asteroid object with specific data values and a little code to test your class.
# *   Add a `__str__(self)` method that returns a nicely formatted string representation of the object, plus a little code to test it.

# %%
@dataclass
class Asteroid:
    """ Represents an asteroid. """
    id: int
    name: str
    estimated_diameter: float
    is_potentially_hazardous: bool
    close_approaches: list

    # Replace __init__ and __str__ methods by using @dataclass
    # def __init__(self, id, name, diameter, hazardous):
    #     self.id = id
    #     self.name = name
    #     self.diameter = diameter
    #     self.hazardous = hazardous
    
    # def __str__(self):
    #     return f'Asteroid ID: {self.id}, Name: {self.name}, Est. Diameter (m): {self.diameter:.2f}, Hazardous (T/F): {self.hazardous}'

    @classmethod
    def from_NEO(cls, neo_id):
        url = f'https://api.nasa.gov/neo/rest/v1/neo/{neo_id}/?api_key={API_KEY}'
        response = requests.request("GET", url, headers={}, data={})
        data = json.loads(response.text)

        name = data['name']
        max_diameter = float(data['estimated_diameter']['meters']['estimated_diameter_max'])
        min_diameter = float(data['estimated_diameter']['meters']['estimated_diameter_min'])
        estimated_diameter = (max_diameter + min_diameter) / 2
        is_potentially_hazardous = data['is_potentially_hazardous_asteroid']
        close_approaches = []

        asteroid = cls(neo_id, name, estimated_diameter, is_potentially_hazardous, close_approaches)
        asteroid.close_approaches = [CloseApproach.from_record(asteroid, approach) for approach in data['close_approach_data']]

        return asteroid

test_asteroid = Asteroid('1234567', '234567 2023 (BB31)', 555.55, True, [])
print(test_asteroid)

test_asteroid_from_id = Asteroid.from_NEO('3014110')
print(test_asteroid_from_id)
# Out:
# Asteroid(id='1234567', name='234567 2023 (BB31)', estimated_diameter=555.55, is_potentially_hazardous=True, close_approaches=[])
# Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_distance=40327112.29697382, r ...

# %% [markdown]
# ## Lab 3 - Exercise 2
# ### Factory method: Asteroid.from_NEO
#
# We want to be able to construct Asteroid objects easily from the NEO API.
#
# Define a `“@classmethod”: from_NEO(cls, neo_id)` that takes the id for a single NEO, fetches the NEO record from the API, then constructs and returns an Asteroid object representing that NEO. This kind of method is sometimes called a “factory” – it constructs an object from raw materials.

# %%
# Add your code to the code cell in Exercise 1

# %% [markdown]
# ## Lab 3 - Exercise 3
# ### Define a CloseApproach class
#
# Each NEO comes with a list of “`close_approach_data`”, where each record in this list represents a single “close approach” to another orbiting body.
#
# *   Develop a class named “**CloseApproach**” to represent a single close approach record. State variables are **asteroid** (Asteroid object),  **orbiting body** (`str`), **approach date** (`datetime` object!),  **miss distance** (`float` choose units, document it, and be consistent!),  and **relative velocity** (ditto).
# *   Define a Factory class method to construct a `CloseApproach` object from one close approach data record (a dictionary object).
#
# Remember to parse the date/time string into a `datetime` object.

# %%
@dataclass
class CloseApproach:
    """ Represents a single close approach record. """
    asteroid: Asteroid
    orbiting_body: str
    approach_date: datetime
    miss_distance: float
    relative_velocity: float

    @classmethod
    def from_record(cls, asteroid, record):
        body = record['orbiting_body']
        date = datetime.datetime.strptime(record['close_approach_date'], '%Y-%m-%d').date()
        distance = float(record['miss_distance']['kilometers'])
        velocity = float(record['relative_velocity']['kilometers_per_hour'])

        return cls(asteroid, body, date, distance, velocity)

test_approach = {
    'close_approach_date': '1900-10-30',
    'close_approach_date_full': '1900-Oct-30 21:14',
    'epoch_date_close_approach': -2182819560000,
    'miss_distance': {
        'astronomical': '0.4183490942',
        'kilometers': '62584133.408749354',
        'lunar': '162.7377976438',
        'miles': '38887977.2407309252'},
    'orbiting_body': 'Earth',
    'relative_velocity': {
        'kilometers_per_hour': '30027.9669430086',
        'kilometers_per_second': '8.3411019286',
        'miles_per_hour': '18658.2109041156'}}

CloseApproach.from_record('3014110', test_approach)
# Out:
# CloseApproach(asteroid='3014110', orbiting_body='Earth', approach_date=datetime.date(1900, 10, 30), miss_distance=62584133.40874936, relative_velocity=30027.9669430086)

# %% [markdown]
# ## Lab 3 - Exercise 4
# ### Add list of close approaches to Asteroid
#
# Every Asteroid should have a list of “close approaches”.  Add a new state variable to your Asteroid class, initially an empty list.  In the factory method, use a list comprehension to build a list of `CloseApproach` objects for the Asteroid from the NEO data record.
#
# Extend your test code to demonstrate this new feature.

# %%
id = test_asteroid_from_id.id
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

# pprint(data)

# Test list comprehension before adding it into the Asteroid class factory method
close_approaches = [CloseApproach.from_record(test_asteroid_from_id, approach) for approach in data['close_approach_data']]

pprint(close_approaches)
# Out:
# [CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
# ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...
#  CloseApproach(asteroid=Asteroid(id='3014110', name='(1998 SU4)', estimated_diameter=236.3429308586, is_potentially_hazardous=True, close_approaches=[CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1901, 1, 23), miss_distance=46578562.94607274, relative_velocity=94290.7642054826), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1908, 9, 20), miss_distance=38539417.48119765, relative_velocity=103801.0019940824), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1912, 3, 20), miss_distance=64334023.67591313, relative_velocity=77694.2599215679), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1913, 9, 6), miss_distance=21602046.840450976, relative_velocity=65813.6151496408), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1917, 2, 5), miss_distance=39908236.52563852, relative_velocity=78525.9998454341), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1922, 1, 10), miss_distance=69207343.86034878, relative_velocity=116891.1009352116), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1924, 9, 27), miss_distance=62315248.51597834, relative_velocity=121081.2081500725), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1928, 4, 5), miss_distance=73743583.07804075, relative_velocity=85300.0041370266), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1929, 9, 10), miss_distance=3872932.988279247, relative_velocity=79060.1565419183), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1933, 2, 19), miss_distance=45863851.43281723, relative_velocity=71449.6847325052), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1934, 9, 8), miss_distance=59099533.28836047, relative_velocity=51910.4125940515), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1938, 1, 19), miss_distance=52998642.25900798, relative_velocity=101697.2229386336), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1945, 9, 16), miss_distance=23405753.310730472, relative_velocity=93379.0505732244), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1949, 3, 7), miss_distance=56081589.51163894, relative_velocity=72609.3928212782), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1950, 9, 4), miss_distance=39211063.193471394, relative_velocity=57126.750569879), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1954, 1, 27), miss_distance=42582393.50637512, relative_velocity=88974.3391963448), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1961, 9, 21), miss_distance=40953546.69057403, relative_velocity=105587.2277098758), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1965, 3, 20), miss_distance=64260785.46557127, relative_velocity=77498.7494092013), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1966, 9, 6), miss_distance=22934555.759161618, relative_velocity=64971.627399698), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1970, 2, 3), miss_distance=39575705.83242728, relative_velocity=80459.9418453926), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1977, 9, 25), miss_distance=53271054.7892319, relative_velocity=114465.6840307061), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1981, 3, 28), miss_distance=69311128.90855955, relative_velocity=81338.3477573296), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1982, 9, 8), miss_distance=12012561.427580606, relative_velocity=71265.7537453242), CloseApproach(asteroid=..., orbiting_body='Earth', approach_date=datetime.date(1986, 2, 9), miss_dista ...

# %% [markdown]
# ## Lab 3 - Optional
# ### Take your skills to the next level!
#
# With this data structure in place, we can now start answering all kinds of interesting questions about a single Asteroid or a set of Asteroids.
#
# Here’s a couple ideas to try:
#
# *   Add a  method to the `Asteroid` class, `closest_earth_approach`, that returns the `CloseApproach` object that represents the closest approach the Asteroid makes to Earth.
#
# *   Write a function named `most_dangerous_approach`, that takes a date range and returns a single “potentially hazardous” Asteroid object that makes the closest approach to Earth in within that range. Your algorithm will ultimately need to:
#
#    *   grab the list of NEO’s for the given date range
#    *   use a list comprehension to build the list of Asteroid objects for the NEOs returned
#    *   use a list comprehension to **filter** potentially hazardous Asteroids only
#    *   use a list comprehension to **map** each Asteroid to its `closest_earth_approach`
#    *   apply Python’s `min` function to identify the Asteroid with the `closest_earth_approach`
#
#    You may want to *decompose* some of these steps into smaller functions.
#
# *   Add a method to the `Asteroid` class, `estimated_mass`, that computes an estimate of the Asteroid’s mass based on its diameter.  This is a model – state your assumptions.
#
# *   Add a method to the `CloseApproach` class, `impact_force`,  that estimates the force of impact if the Asteroid hit the orbiting object.  Again, this is a model, state your assumptions.

# %%
# Add a closest_earth_approach method

# %%
# Write a function most_dangerous_approach

# %%
# Add an estimated_mass method

# %%
# Add an impact_force method
